# %%
from datetime import datetime
from dataclasses import dataclass


class Connection:
    def __init__(self, line, departure_time, arrival_time, start_latitude, start_longitude, end_latitude, end_longitude, end_stop):
        self.line: str = line
        self.departure_time: datetime = departure_time
        self.arrival_time: datetime = arrival_time
        self.start_latitude: float = start_latitude
        self.start_longitude: float = start_longitude
        self.end_latitude: float = end_latitude
        self.end_longitude: float = end_longitude
        self.end_stop: str = end_stop
        
    def __repr__(self):
        return f"Connection({self.line}, {self.departure_time.strftime('%H:%M:%S')} -> {self.arrival_time.strftime('%H:%M:%S')}, {self.end_stop})"


    def toDict(self):
        return {
            'line': self.line,
            'departure_time': self.departure_time.strftime('%H:%M:%S'),
            'arrival_time': self.arrival_time.strftime('%H:%M:%S'),
            'start_latitude': self.start_latitude,
            'start_longitude': self.start_longitude,
            'end_latitude': self.end_latitude,
            'end_longitude': self.end_longitude,
            'end_stop': self.end_stop
        }


class BusStop:
    def __init__(self, name: str):
        self.name: str = name
        self.connections: dict[str, list[Connection]] = {}

    def add_connection(self, end_stop: str, connection: Connection):
        if end_stop not in self.connections:
            self.connections[end_stop] = [connection]
        else:
            self.connections[end_stop].append(connection)
    
    def __repr__(self):
        return f"BusStop({self.name}, {len(self.connections)} connections)"
    
    def toDict(self):
        return {
            'name': self.name,
            'connections': {k: [x.toDict() for x in v] for k, v in self.connections.items()}
        }

# %%
import pandas as pd
from datetime import datetime

datetime_format = '%Y-%m-%d %H:%M:%S'


def convert_time(time: str) -> datetime:
    hour = int(time[:2])
    if hour >= 24:
        hour -= 24
        return datetime.strptime(f'2025-01-02 {hour:02}{time[2:]}', datetime_format)
    else:
        return datetime.strptime(f'2025-01-01 {time}', datetime_format)


def add_connection(graph: dict[str, BusStop], start_stop: str,
                   end_stop: str, connection: Connection):
    if start_stop not in graph:
        graph[start_stop] = BusStop(name=start_stop)
    if end_stop not in graph:
        graph[end_stop] = BusStop(name=end_stop)
    graph[start_stop].add_connection(end_stop, connection)


def load_csv_data(filename: str):
    df = pd.read_csv(filename)
    graph: dict[str, BusStop] = {}

    for index, row in df.iterrows():
        start_stop = row['start_stop']
        end_stop = row['end_stop']
        departure_time = convert_time(row['departure_time'])
        arrival_time = convert_time(row['arrival_time'])
        start_lat = row['start_stop_lat']
        start_lon = row['start_stop_lon']
        end_lat = row['end_stop_lat']
        end_lon = row['end_stop_lon']
        connection = Connection(
            line=row['line'],
            departure_time=departure_time,
            arrival_time=arrival_time,
            start_latitude=start_lat,
            start_longitude=start_lon,
            end_latitude=end_lat,
            end_longitude=end_lon,
            end_stop=end_stop
        )
        add_connection(graph, start_stop, end_stop, connection)
    
    return graph

# %%
graph = load_csv_data('mpk_indexed.csv')
# Out:
# /var/folders/03/n179cc412h58x4qb9mt1bv_m0000gn/T/ipykernel_79092/4144027882.py:26: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(filename)

# %%
import pickle

with open('mpk_graph.pickle', 'wb') as f:
    pickle.dump(graph, f)

# %%
import pickle

with open('mpk_graph.pickle', 'rb') as f:
    graph = pickle.load(f)

# %%
from datetime import timedelta

def find_earliest_connection(connections: list[Connection], current_time: datetime, previous_line=None, transfer_time=2) -> Connection:

    earliest = None
    earliest_departure = None
    
    for conn in connections:
        required_time = current_time
        if previous_line is not None and conn.line != previous_line:
            required_time = current_time + timedelta(minutes=transfer_time)
        
        if conn.departure_time >= required_time and (earliest is None or conn.departure_time < earliest_departure):
            earliest = conn
            earliest_departure = conn.departure_time
    
    return earliest

# %%
import heapq
from datetime import timedelta

# %%
def dijkstra(start_stop: str, end_stop: str, departure_time: str, graph: dict[str, BusStop], transfer_time: int = 2):

    if start_stop not in graph or end_stop not in graph:
        return None, []

    start_time = convert_time(departure_time)

    distances = {stop: float('inf') for stop in graph}
    previous = {stop: None for stop in graph}
    arrival_times = {stop: None for stop in graph}
    previous_lines = {stop: None for stop in graph}

    distances[start_stop] = 0
    arrival_times[start_stop] = start_time

    priority_queue = [(0, start_stop)]

    visited_nodes = 0
    visited_connections = 0

    while priority_queue:
        current_distance, current_stop = heapq.heappop(priority_queue)

        if current_stop == end_stop:
            break

        if current_distance > distances[current_stop]:
            continue

        visited_nodes += 1 

        current_time = arrival_times[current_stop]
        current_line = previous_lines[current_stop]

        for next_stop, connections in graph[current_stop].connections.items():
            visited_connections += 1  

            earliest_conn = find_earliest_connection(
                connections, 
                current_time, 
                previous_line=current_line, 
                transfer_time=transfer_time
            )

            if earliest_conn is None:
                continue

            travel_time = (earliest_conn.arrival_time - current_time).total_seconds() / 60

            if distances[current_stop] + travel_time < distances[next_stop]:
                distances[next_stop] = distances[current_stop] + travel_time
                previous[next_stop] = (current_stop, earliest_conn)
                arrival_times[next_stop] = earliest_conn.arrival_time
                previous_lines[next_stop] = earliest_conn.line

                heapq.heappush(priority_queue, (distances[next_stop], next_stop))

    print(f"Odwiedzone węzły: {visited_nodes}, odwiedzone krawędzie: {visited_connections}")

    route = []
    current_stop = end_stop
    while current_stop and previous[current_stop]:
        prev_stop, conn = previous[current_stop]
        route.append(conn)
        current_stop = prev_stop

    route.reverse()

    total_time = distances[end_stop] if distances[end_stop] != float('inf') else None
    return total_time, route


def print_path(total_time, route):
    print(f"Czas przejazdu: {total_time} min")
    for conn in route:
        print(f"{conn.line} {conn.departure_time.strftime('%H:%M:%S')} -> {conn.arrival_time.strftime('%H:%M:%S')} {conn.end_stop}")

# %%
start = "Iwiny - rondo"
end = "Psie Pole (Rondo Lotników Polskich)"
departure = "11:25:00"

total_time, route = dijkstra(start, end, departure, graph)
print_path(total_time, route)
# Out:
# Odwiedzone węzły: 400, odwiedzone krawędzie: 1209
# Czas przejazdu: 58.0 min
# 110 11:25:00 -> 11:26:00 Vivaldiego
# 110 11:26:00 -> 11:28:00 Kajdasza
# 110 11:28:00 -> 11:30:00 Jagodzińska
# 110 11:30:00 -> 11:31:00 Malinowskiego
# 110 11:31:00 -> 11:32:00 Konduktorska
# 110 11:32:00 -> 11:33:00 Buforowa-Rondo
# 110 11:33:00 -> 11:34:00 BARDZKA (Cmentarz)
# 110 11:34:00 -> 11:35:00 Morwowa
# 110 11:35:00 -> 11:36:00 Krynicka
# 110 11:36:00 -> 11:38:00 Bardzka
# 110 11:38:00 -> 11:40:00 Kamienna
# 110 11:40:00 -> 11:41:00 Prudnicka
# 110 11:41:00 -> 11:42:00 Hubska (Dawida)
# 16 11:47:00 -> 11:51:00 Kościuszki
# 16 11:51:00 -> 11:52:00 Komuny Paryskiej
# 16 11:52:00 -> 11:54:00 pl. Wróblewskiego
# 16 11:54:00 -> 11:56:00 Urząd Wojewódzki (Impart)
# 16 11:56:00 -> 11:58:00 most Grunwaldzki
# 16 11:58:00 -> 12:00:00 PL. GRUNWALDZKI
# 16 12:00:00 -> 12:02:00 Piastowska
# 16 12:02:00 -> 12:04:00 Prusa
# 16 12:04:00 -> 12:05:00 Wyszyńskiego
# 914 12:07:00 -> 12:08:00 Damrota
# 914 12:08:00 -> 12:11:00 KROMERA
# 914 12:11:00 -> 12:13:00 Kromera (Czajkowskiego)
# 914 12:13:00 -> 12:14:00 Grudziądzka
# 914 12:14:00 -> 12:16:00 Brücknera
# 914 12:16:00 -> 12:18:00 C.H. Korona
# 914 12:18:00 -> 12:20:00 Zielna
# 914 12:20:00 -> 12:21:00 Psie Pole
# 914 12:21:00 -> 12:23:00 Psie Pole (Rondo Lotników Polskich)

# %%
import heapq
from datetime import datetime
from typing import Callable, List, Dict, Optional, Tuple

def astar(
    start_stop: str, 
    end_stop: str, 
    departure_time: str, 
    graph: dict[str, BusStop], 
    heuristic_function: Callable[[str, str, Dict[str, BusStop]], float],
    transfer_time: int = 2
):

    if start_stop not in graph:
        return None, []
    if end_stop not in graph:
        return None, []

    start_time = convert_time(departure_time)

    distances = {stop: float('inf') for stop in graph}
    previous = {stop: None for stop in graph}
    arrival_times = {stop: None for stop in graph}
    previous_lines = {stop: None for stop in graph}

    distances[start_stop] = 0
    arrival_times[start_stop] = start_time

    priority_queue = [(0 + heuristic_function(start_stop, end_stop, graph), start_stop)]

    visited_nodes = 0
    visited_connections = 0

    while priority_queue:
        print("loop")
        current_f_score, current_stop = heapq.heappop(priority_queue)


        if current_stop == end_stop:
            break

        current_h_score = heuristic_function(current_stop, end_stop, graph)
        current_g_score = current_f_score - current_h_score
        
        if current_g_score > distances[current_stop]:
            continue

        visited_nodes += 1

        current_time = arrival_times[current_stop]
        current_line = previous_lines[current_stop]

        for next_stop, connections in graph[current_stop].connections.items():
            print(next_stop)
            visited_connections += 1


            earliest_conn = find_earliest_connection(
                connections, 
                current_time, 
                previous_line=current_line, 
                transfer_time=transfer_time
            )

            if earliest_conn is None:
                continue

            travel_time = (earliest_conn.arrival_time - current_time).total_seconds() / 60

            change = False
            if current_line and earliest_conn.line != current_line:
                change = True

            if distances[current_stop] + travel_time < distances[next_stop]:
                distances[next_stop] = distances[current_stop] + travel_time
                previous[next_stop] = (current_stop, earliest_conn)
                arrival_times[next_stop] = earliest_conn.arrival_time
                previous_lines[next_stop] = earliest_conn.line

                next_h_score = heuristic_function(next_stop, end_stop, graph, 
                                                  current_stop=current_stop,
                                                  change=change
                                                  )
                heapq.heappush(priority_queue, (distances[next_stop] + next_h_score, next_stop))


    if distances[end_stop] == float('inf') or previous[end_stop] is None:
        print(distances[end_stop] == float('inf'))
        print(previous[end_stop] is None)
        print("Nie znaleziono gowna.")
        return None, []

    route = []
    current_stop = end_stop
    while current_stop and previous[current_stop]:
        prev_stop, conn = previous[current_stop]
        route.append(conn)
        current_stop = prev_stop

    route.reverse()

    total_time = distances[end_stop] if distances[end_stop] != float('inf') else None
    print(f"Odwiedzone węzły: {visited_nodes}, odwiedzone krawędzie: {visited_connections}")
    return total_time, route

# %%
def zero_heuristic(next_stop: str, target_stop: str, graph: Dict[str, BusStop], current_stop=None, change=None) -> float:
    return 0

# %%
import math

def extract_first_connection(stop_name: str, graph: Dict[str, BusStop]):
    try:
        for next_stop, connections in graph[stop_name].connections.items():
            if connections: 
                return connections[0]
    except (KeyError, IndexError):
        pass
    return None


def euclidean_distance(x1, x2, y1, y2):
    return math.sqrt((x1 - x2)**2 + (y1 - y2)**2)

def euclidean_distance_heuristic(next_stop: str, target_stop: str, graph: Dict[str, BusStop],
                                  current_stop=None, change=None) -> float:
    first_next_conn = extract_first_connection(next_stop, graph)
    first_target_conn = extract_first_connection(target_stop, graph)
    
    if first_next_conn is None or first_target_conn is None:
        return 0
    
    dist = euclidean_distance(
        first_next_conn.start_latitude, first_target_conn.start_latitude,
        first_next_conn.start_longitude, first_target_conn.start_longitude
    )
    
    # Konwersja do minut podróży
    # 1 stopień szerokości/długości geograficznej to około 111 km
    # średnia prędkość 30 km/h -> 0.5 km/min
    travel_time_estimate = dist * 111 / 0.4
    
    return travel_time_estimate * 0.2

# %%
def euclidean_distance_heuristic_2(next_stop: str, target_stop: str, graph: Dict[str, BusStop],
                                  current_stop=None, change=None) -> float:
    first_next_conn = extract_first_connection(next_stop, graph)
    first_target_conn = extract_first_connection(target_stop, graph)
    
    if first_next_conn is None or first_target_conn is None:
        return 0
    
    dist = euclidean_distance(
        first_next_conn.start_latitude, first_target_conn.start_latitude,
        first_next_conn.start_longitude, first_target_conn.start_longitude
    )
    
    # Konwersja do minut podróży
    # 1 stopień szerokości/długości geograficznej to około 111 km
    # średnia prędkość 30 km/h -> 0.5 km/min
    travel_time_estimate = dist * 111 / 0.4
    
    if change:
        return travel_time_estimate * 0.5
    else:
        return 0

# %%
def angle_between_heuristic(next_stop: str, 
                            target_stop: str, 
                            graph: Dict[str, BusStop], 
                            current_stop=None, 
                            change=None
                            ) -> float:
    
    try:
    
        first_next_conn = extract_first_connection(next_stop, graph)
        first_target_conn = extract_first_connection(target_stop, graph)
        first_current_conn = extract_first_connection(current_stop, graph)

        curr_target_dist = euclidean_distance(first_current_conn.start_latitude, first_target_conn.start_latitude,
                                            first_current_conn.start_longitude, first_target_conn.start_longitude)
        
        curr_next_dist = euclidean_distance(first_current_conn.start_latitude, first_next_conn.start_latitude,
                                            first_current_conn.start_longitude, first_next_conn.start_longitude)
        
        next_target_dist = euclidean_distance(first_target_conn.start_latitude, first_next_conn.start_latitude,
                                            first_target_conn.start_longitude, first_next_conn.start_longitude)
        

        cos = (next_target_dist**2- curr_target_dist**2 - curr_next_dist**2) / ( -2.0 * curr_target_dist * curr_next_dist)


        if change and cos < 0.5:
            return (2.5 - cos)
        return 0    
    except:
        return 0

# %%
print(graph)
# Out:
# {'Zajezdnia Obornicka': BusStop(Zajezdnia Obornicka, 3 connections), 'Paprotna': BusStop(Paprotna, 3 connections), 'Obornicka (Wołowska)': BusStop(Obornicka (Wołowska), 1 connections), 'Bezpieczna': BusStop(Bezpieczna, 4 connections), 'Bałtycka': BusStop(Bałtycka, 5 connections), 'Broniewskiego': BusStop(Broniewskiego, 5 connections), 'Pola': BusStop(Pola, 2 connections), 'Syrokomli': BusStop(Syrokomli, 3 connections), 'Kasprowicza': BusStop(Kasprowicza, 3 connections), 'pl. Daniłowskiego': BusStop(pl. Daniłowskiego, 3 connections), 'Przybyszewskiego': BusStop(Przybyszewskiego, 1 connections), 'Czajkowskiego': BusStop(Czajkowskiego, 2 connections), 'KOSZAROWA (Uniwersytet)': BusStop(KOSZAROWA (Uniwersytet), 1 connections), 'KOSZAROWA (Szpital)': BusStop(KOSZAROWA (Szpital), 1 connections), 'Berenta': BusStop(Berenta, 3 connections), 'KROMERA': BusStop(KROMERA, 7 connections), 'Mosty Warszawskie': BusStop(Mosty Warszawskie, 3 connections), 'Wyszyńskiego': BusStop(Wyszyńskiego, 4 connections), 'Ogród Botaniczny': BusStop(Ogród Botaniczny, 5 connections), 'Katedra': BusStop(Katedra, 3 connections), 'Urząd Wojewódzki (Muzeum Narodowe)': BusStop(Urząd Wojewódzki (Muzeum Narodowe), 4 connections), 'Poczta Główna': BusStop(Poczta Główna, 2 connections), 'skwer Krasińskiego': BusStop(skwer Krasińskiego, 4 connections), 'Wzgórze Partyzantów': BusStop(Wzgórze Partyzantów, 4 connections), 'Renoma': BusStop(Renoma, 6 connections), 'Arkady (Capitol)': BusStop(Arkady (Capitol), 13 connections), 'Pl. Hirszfelda': BusStop(Pl. Hirszfelda, 3 connections), 'Krucza': BusStop(Krucza, 6 connections), 'Krucza (Mielecka)': BusStop(Krucza (Mielecka), 3 connections), 'Inżynierska': BusStop(Inżynierska, 3 connections), 'Aleja Pracy': BusStop(Aleja Pracy, 3 connections), 'FAT': BusStop(FAT, 9 connections), 'GRABISZYŃSKA (Cmentarz)': BusStop(GRABISZYŃSKA (Cmentarz), 4 connections), 'Solskiego': BusStop(Solskiego, 3 connections), 'Wiejska': BusStop(Wiejska, 6 connections), 'Kadłubka': BusStop(Kadłubka, 2 connections), 'Stanki': BusStop(Stanki, 2 connections), 'Bukowskiego': BusStop(Bukowskiego, 2 connections), 'RACŁAWICKA': BusStop(RACŁAWICKA, 3 connections), 'Rymarska': BusStop(Rymarska, 3 connections), 'Wawrzyniaka': BusStop(Wawrzyniaka, 3 connections), 'Chłodna': BusStop(Chłodna, 2 connections), 'Sowia': BusStop(Sowia, 3 connections), 'KRZYKI': BusStop(KRZYKI, 10 connections), 'Dworzec Główny (Dworcowa)': BusStop(Dworzec Główny (Dworcowa), 3 connections), 'Krasińskiego': BusStop(Krasińskiego, 2 connections), 'Damrota': BusStop(Damrota, 1 connections), 'Koszarowa': BusStop(Koszarowa, 2 connections), 'Sołtysowicka': BusStop(Sołtysowicka, 2 connections), 'Poprzeczna': BusStop(Poprzeczna, 2 connections), 'Redycka': BusStop(Redycka, 2 connections), 'Bagatela': BusStop(Bagatela, 2 connections), 'SOŁTYSOWICE': BusStop(SOŁTYSOWICE, 1 connections), 'POŚWIĘTNE': BusStop(POŚWIĘTNE, 3 connections), 'Wołowska': BusStop(Wołowska, 2 connections), 'Kępińska': BusStop(Kępińska, 2 connections), 'Kamieńskiego': BusStop(Kamieńskiego, 4 connections), 'Grudziądzka': BusStop(Grudziądzka, 2 connections), 'Brücknera': BusStop(Brücknera, 5 connections), 'Psie Pole': BusStop(Psie Pole, 3 connections), 'Psie Pole (Rondo Lotników Polskich)': BusStop(Psie Pole (Rondo Lotników Polskich), 7 connections), 'Zakrzowska': BusStop(Zakrzowska, 3 connections), 'Kopańskiego': BusStop(Kopańskiego, 1 connections), 'Wallenroda': BusStop(Wallenroda, 3 connections), 'Królewska': BusStop(Królewska, 4 connections), 'OSIEDLE SOBIESKIEGO': BusStop(OSIEDLE SOBIESKIEGO, 1 connections), 'Kwidzyńska': BusStop(Kwidzyńska, 5 connections), 'Zacisze': BusStop(Zacisze, 2 connections), 'Śniadeckich': BusStop(Śniadeckich, 3 connections), 'Kochanowskiego': BusStop(Kochanowskiego, 5 connections), 'PL. GRUNWALDZKI': BusStop(PL. GRUNWALDZKI, 7 connections), 'most Grunwaldzki': BusStop(most Grunwaldzki, 4 connections), 'GALERIA DOMINIKAŃSKA': BusStop(GALERIA DOMINIKAŃSKA, 14 connections), 'EPI': BusStop(EPI, 6 connec ...

# %%
start = "Iwiny - rondo"
end = "Psie Pole (Rondo Lotników Polskich)"
departure = "12:00:00"

total_time, route = astar(start, end, departure, graph, heuristic_function=zero_heuristic)
# print(total_time)
# print_path(total_time, route)


def serialize_route(route):
    return [(conn.line, conn.departure_time, conn.arrival_time, 
                conn.end_stop, conn.start_latitude, conn.start_longitude) for conn in route]

serialize_route(route)
# Out:
# loop
# Vivaldiego
# Iwiny - Kolejowa
# loop
# Kajdasza
# Iwiny - rondo
# loop
# Jagodzińska
# Vivaldiego
# loop
# Malinowskiego
# Kajdasza
# loop
# Konduktorska
# Jagodzińska
# ROD Zgoda
# Lutosławskiego
# loop
# Buforowa-Rondo
# Malinowskiego
# loop
# BARDZKA (Cmentarz)
# Konduktorska
# ROD Zgoda
# loop
# Morwowa
# Buforowa-Rondo
# GAJ - pętla
# loop
# Świeradowska
# Morwowa
# loop
# GAJ - pętla
# GAJ
# Morwowa
# loop
# Świeradowska
# Działkowa
# GAJ - pętla
# Borowska (Szpital)
# loop
# GAJ
# Śliczna
# ROD Bajki
# Borowska (Szpital)
# loop
# Asfaltowa (szkoła)
# Malinowskiego
# loop
# Klasztorna
# Lutosławskiego
# loop
# Świeradowska
# Krynicka
# Złotostocka
# BARDZKA (Cmentarz)
# loop
# Śliczna
# Działkowa
# Orzechowa
# SPISKA (Ośrodek sportu)
# loop
# Tunelowa
# Konduktorska
# loop
# Parafialna
# Asfaltowa (szkoła)
# loop
# Morwowa
# Bardzka
# GAJ - pętla
# loop
# ROD Mieczyk
# ROD Zgoda
# loop
# Działkowa
# Borowska (Aquapark)
# ROD Bajki
# Uniwersytet Ekonomiczny
# loop
# Park Brochowski
# Tunelowa
# loop
# Nyska
# Kamienna
# Krynicka
# Orzechowa
# loop
# Śliczna
# DWORZEC AUTOBUSOWY
# Uniwersytet Ekonomiczny
# Wapienna
# PETRUSEWICZA
# loop
# Wojszyce
# Świt
# Oboźna
# Klasztorna
# loop
# Chińska
# ROD Mieczyk
# loop
# BROCHÓW
# BROCHÓW (Stacja kolejowa)
# Semaforowa
# loop
# Ziemniaczana
# Chińska
# Iwiny - Brochowska/Polna
# loop
# Bardzka
# Prudnicka
# Wapienna
# loop
# TARNOGAJ
# GAJ - pętla
# Klimasa
# loop
# Działkowa
# Przystankowa
# GAJ
# loop
# Tarnogajska
# Bardzka
# loop
# Kamienna
# Gajowa
# Hubska (Dawida)
# loop
# Klimasa
# Gazowa
# Złotostocka
# TARNOGAJ
# loop
# Borowska (Aquapark)
# Widna
# loop
# Dyrekcyjna
# Borowska (Aquapark)
# DWORZEC GŁÓWNY
# PETRUSEWICZA
# Sanocka
# Dworzec Główny (Stawowa)
# Joannitów
# DWORZEC AUTOBUSOWY
# Hubska (Dawida)
# EPI
# loop
# Prudnicka
# Kościuszki
# Gajowa
# Pułaskiego
# DWORZEC AUTOBUSOWY
# loop
# Borowska (Szpital)
# Wojszyce
# loop
# Klimasa
# Nyska
# Bardzka
# Armii Krajowej (Bogedaina)
# loop
# Zajezdnia GAJ
# Sanocka
# Wiśniowa
# Drukarska
# Borowska (Aquapark)
# Śliczna
# PETRUSEWICZA
# loop
# Kamienna
# loop
# Chińska
# Topolowa
# loop
# Przystankowa
# Parafialna
# loop
# Rondo
# Uniwersytet Ekonomiczny
# Hallera
# loop
# Karwińska
# TARNOGAJ
# Wiaduktowa
# loop
# TARNOGAJ
# Tarnogajska
# Armii Krajowej (Bogedaina)
# Złotostocka
# loop
# DWORZEC AUTOBUSOWY
# GALERIA DOMINIKAŃSKA
# Arkady (Capitol)
# Wzgórze Partyzantów
# DWORZEC GŁÓWNY
# Pułaskiego
# Dworzec Główny (Dworcowa)
# EPI
# Kościuszki
# Dworzec Główny (Stawowa)
# loop
# Arkady (Capitol)
# DWORZEC AUTOBUSOWY
# Hallera
# loop
# PETRUSEWICZA
# Borowska (Aquapark)
# loop
# Prudnicka
# Joannitów
# Hubska (Dawida)
# PETRUSEWICZA
# loop
# Bardzka
# ROD Bajki
# loop
# Uniwersytet Ekonomiczny
# DWORZEC AUTOBUSOWY
# Joannitów
# loop
# BROCHÓW (Stacja kolejowa)
# Wiaduktowa
# loop
# Topolowa
# Karwińska
# Gazowa
# loop
# Park Wschodni
# Tarnogajska
# Armii Krajowej
# Klimasa
# loop
# DWORZEC AUTOBUSOWY
# Gwiaździsta
# Arena
# Arkady (Capitol)
# Zaolziańska
# DWORZEC GŁÓWNY
# loop
# Gałczyńskiego
# Parafialna
# loop
# ROD Bajki
# Wiśniowa
# loop
# loop
# Pl. Hirszfelda
# Dworzec Główny (Dworcowa)
# EPI
# Rondo
# GALERIA DOMINIKAŃSKA
# Świdnicka
# Zaolziańska
# DWORZEC GŁÓWNY
# Renoma
# pl. Legionów
# DWORZEC AUTOBUSOWY
# pl. Orląt Lwowskich
# Hallera
# loop
# Grota-Roweckiego
# Oboźna
# Biestrzyków - Wrocławska
# loop
# Gajowa
# DWORZEC AUTOBUSOWY
# Sanocka
# loop
# Jaworowa
# Uniwersytet Ekonomiczny
# Sudecka
# SPISKA (Ośrodek sportu)
# loop
# skwer Krasińskiego
# Wzgórze Partyzantów
# Kościuszki
# loop
# Piłsudskiego
# Zielińskiego
# loop
# Orla
# Rondo
# Jastrzębia
# Sztabowa
# Gajowicka
# Racławicka (szkoła)
# Sudecka
# Drukarska
# KRZYKI
# PETRUSEWICZA
# DWORZEC GŁÓWNY
# loop
# Weigla (Szpital)
# Wiśniowa
# loop
# loop
# loop
# Karwińska
# Armii Krajowej
# loop
# Kurpiów
# Gałczyńskiego
# loop
# EPI
# pl. Orląt Lwowskich
# Zielińskiego
# loop
# Park Brochowski
# loop
# Pułtuska
# Jaworowa
# loop
# Kolejowa
# Arkady (Capitol)
# pl. Orląt Lwowskich
# Narodowe Forum Muzyki
# Piłsudskiego
# Grabiszyńska
# loop
# Park Wschodni
# KRAKOWSKA (Centrum handlowe)
# Armii Krajowej (Bogedaina)
# Międzyrzecka
# loop
# Głubczycka
# Park Wschodni
# KSIĘŻE MAŁE
# Gazowa
# Wiaduktowa
# loop
# Ołtaszyn
# Grota-Roweckiego
# loop
# PARK POŁUDNIOWY
# Weigla (Szpital)
# Wyścigowa
# Pułtuska
# loop
# Modlińska
# loop
# loop
# Renoma
# DWORZEC GŁÓWNY
# GALERIA DOMINIKAŃSKA
# Park Staromiejski
# loop
# Wzgórze Partyzantów
# Krasińskiego
# Dworzec Główny (Dworcowa)
# DWORZEC GŁÓWNY
# loop
# loop
# Orla
# Hallera
# loop
# Pułaskiego
# Komuny Paryskiej
# Hubska (Dawida)
# Świstackiego
# loop
# Urząd Wojewódzki (Muzeum Narodowe)
# Urząd Wojewódzki (Impart)
# loop
# Świt
# Kutrzeby
# Strachowskiego
# Kurpiów
# loop
# Pułtuska
# Wyścigowa
# KRZYKI
# Hippiczna
# loop
# DWORZEC GŁÓWNY
# Kościuszki
# Hubska (Dawida)
# loop
# Hallera
# Rondo
# loop
# Wielka
# Arkady (Capitol)
# EPI
# loop
# PL. JANA PAWŁA II
# pl. Legionów
# Renoma
# Dworzec Świebodzki
# Tęczowa
# loop
# Mielecka
# Hallera
# Krucza
# loop
# Głubczycka
# Księska
# Karwińska
# Zagłębiowska
# loop
# loop
# Grabiszyńska
# pl. Legionów
# loop
# Kościuszki
# pl. Wróblewskiego
# Komuny Paryskiej (szkoła)
# loop
# Bierdzany
# Rakowiecka
# Biegasa
# Armii Krajowej
# Okólna
# loop
# Wawrzyniaka
# Gajowicka (szkoła)
# Rymarska
# loop
# KRZYKI
# Hallera
# Jastrzębia
# Zajezdnia BOREK
# loop
# DWORZEC AUTOBUSOWY
# Sanocka
# Joannitów
# Borowska (Aquapark)
# loop
# Hallera
# Arkady (Capitol)
# Sztabowa
# Wielka
# Krucza
# Drukarska
# Zaporoska
# loop
# Rondo
# Zaolziańska
# loop
# Renoma
# Urząd Wojewódzki (Impart)
# DWORZEC GŁÓWNY
# Świdnicka
# Dworzec Główny (Dworcowa)
# Urząd Wojewódzki (Muzeum Narodowe)
# Wzgórze Partyzantów
# pl. Wróblewskiego
# Park Staromiejski
# Oławska
# pl. Nowy Targ
# GALERIA DOMINIKAŃSKA
# skwer Krasińskiego
# Hala Targowa
# loop
# Pereca
# Kolejowa
# Zaporoska
# Tęczowa
# pl. Legionów
# loop
# Krucza (Mielecka)
# Pl. Hirszfelda
# Grochowa
# Rondo
# Żelazna
# Gajowicka
# loop
# Arkady (Capitol)
# Opera
# pl. Orląt Lwowskich
# Dworzec Główny (Dworcowa)
# DWORZEC GŁÓWNY
# Świdnicka
# loop
# Wawrzyniaka
# RACŁAWICKA
# Modlińska
# loop
# KSIĘŻE MAŁE
# Sosnowiecka
# loop
# loop
# Chełmońskiego
# Międzyrzecka
# loop
# pl. Orląt Lwowskich
# Smolecka
# loop
# Arkady (Capitol)
# Park Staromiejski
# ŚWIDNICKA (Dom Europy)
# loop
# Rynek
# Młodych Techników
# Kępa Mieszczańska
# PL. JANA PAWŁA II
# pl. Orląt Lwowskich
# Inowrocławska
# loop
# Rymarska
# Bukowskiego
# RACŁAWICKA
# loop
# Zagłębiowska
# Brochowska
# loop
# rondo Św. Ojca Pio
# Ołtaszyn
# loop
# most Grunwaldzki
# pl. Wróblewskiego
# GALERIA DOMINIKAŃSKA
# PL. GRUNWALDZKI
# loop
# Malinowa
# PARK POŁUDNIOWY
# Wojszycka
# Pułtuska
# Skierniewicka
# loop
# pl. Zgody (Muzeum Etnograficzne)
# GALERIA DOMINIKAŃSKA
# Komuny Paryskiej
# Urząd Wojewódzki (Impart)
# Na Grobli (Hydropolis)
# loop
# Sosnowiecka
# KSIĘŻE WIELKIE
# loop
# RACŁAWICKA
# Stanki
# loop
# Piramowicza (Kampus Biskupin)
# Tramwajowa
# Dembowskiego (Kosiby)
# Biegasa
# Partyzantów
# loop
# loop
# KSIĘŻE MAŁE
# Karwińska
# loop
# Armii Krajowej
# Krakowska
# loop
# Sowia
# Zimowa
# Orla
# Radio i Telewizja
# Zajezdnia BOREK
# Przyjaźni
# PARK POŁUDNIOWY
# KRZYKI
# Partynice (tor wyścigów konnych)
# Hallera
# loop
# Ożynowa
# Wyścigowa
# loop
# Ojca Beyzyma
# Gajowicka
# loop
# loop
# ŚWIDNICKA (Dom Europy)
# Opera
# GALERIA DOMINIKAŃSKA
# Wzgórze Partyzantów
# loop
# Stalowa
# Grabiszyńska
# loop
# loop
# loop
# Hallera
# Wiśniowa
# Jarzębinowa
# loop
# Poczta Główna
# PL. GRUNWALDZKI
# Urząd Wojewódzki (Impart)
# Urząd Wojewódzki (Muzeum Narodowe)
# loop
# Świdnicka
# Oławska
# loop
# Na Niskich Łąkach
# Komuny Paryskiej
# loop
# Zaporoska
# loop
# Sudecka
# Skierniewicka
# loop
# Brochowska
# loop
# KRAKOWSKA (Centrum handlowe)
# Na Niskich Łąkach
# loop
# Aleja Pracy
# Mielecka
# GRABISZYNEK
# Aleja Wędrowców
# loop
# rondo Św. Ojca Pio
# Malinowa
# loop
# Dworzec Świebodzki
# Śrubowa
# loop
# Bukowskiego
# Kadłubka
# loop
# Poczta Główna
# Katedra
# GALERIA DOMINIKAŃSKA
# pl. Wróblewskiego
# loop
# 8 Maja
# Chełmońskiego
# Tramwajowa
# loop
# PL. SOLIDARNOŚCI
# Szczepin
# loop
# Stanki
# Wiejska
# loop
# Krakowska
# pl. Zgody (Muzeum Etnograficzne)
# Na Niskich Łąkach
# Świstackiego
# Rakowiecka
# loop
# Wita Stwosza
# loop
# most Grunwaldzki
# Kochanowskiego
# Kliniki - Politechnika Wrocławska
# Piastowska
# Reja
# Bujwida
# PL. GRUNWALDZKI
# loop
# Jarzębinowa
# Wyścigowa
# loop
# pl. Srebrny
# Pereca
# Grochowa
# loop
# Wyścigowa
# loop
# Rondo
# Grabiszyńska
# Krucza
# Zielińskiego
# loop
# Hala Targowa
# GALERIA DOMINIKAŃSKA
# loop
# Wysoka - osiedle
# rondo Św. Ojca Pio
# Ożynowa
# Husarska
# Strachowskiego
# ZWYCIĘSKA
# loop
# Wrocławski Park Przemysłowy
# Dolmed
# Smolecka
# pl. Strzegomski (Muzeum Współczesne)
# loop
# Rynek
# GALERIA DOMINIKAŃSKA
# Zamkowa
# Opera
# Oławska
# Park Staromiejski
# loop
# FAT
# Inżynierska
# Ojca Beyzyma
# loop
# loop
# Gajowicka
# loop
# pl. Bema
# pl. Nowy Targ
# Dubois
# GALERIA DOMINIKAŃSKA
# loop
# Urząd Wojewódzki (Muzeum Narodowe)
# Ogród Botaniczny
# Reja
# loop
# Pomorska
# PL. JANA PAWŁA II
# Michalczyka
# pl. Strzelecki
# loop
# Renoma
# pl. Legionów
# Zamkowa
# loop
# KRZYKI
# Chłodna
# Zimowa
# loop
# loop
# Chełmońskiego
# ZOO
# Hala Stulecia
# loop
# Kadłubka
# Solskiego
# Adamieckiego
# Jordanowska
# WAŁBRZYSKA
# FAT
# loop
# Ossolineum (Uniwersytecka)
# loop
# Park Biznesu
# Śrubowa
# Uniwersytet Dolnośląski DSW
# loop
# Świdnicka
# Rynek
# Narodowe Forum Muzyki
# loop
# Arabska
# BROCHÓW
# loop
# Os. Przyjaźni
# KRZYKI
# Sowia
# loop
# Bzowa (Centrum Historii Zajezdnia)
# Stalowa
# loop
# Stadion Olimpijski
# Godebskiego (AWF Wrocław)
# Park Szczytnicki
# Dembowskiego (Kosiby)
# loop
# Ślusarska
# Ojca Beyzyma
# loop
# BIEŃKOWICE
# Ziemniaczana
# loop
# Hutmen
# pl. Srebrny
# loop
# Sowia
# Wawrzyniaka
# loop
# Stalowa
# Krucza
# loop
# Partynice (tor wyścigów konnych)
# rondo Św. Ojca Pio
# loop
# loop
# Hala Stulecia
# PL. GRUNWALDZKI
# Mickiewicza
# loop
# PL. JANA PAWŁA II
# pl. Strzegomski (Muzeum Współczesne)
# Strzegomska (Muzeum Współczesne)
# loop
# Skarbowców
# Zimowa
# loop
# Dubois
# loop
# Wiejska
# GRABISZYŃSKA (Cmentarz)
# OPORÓW
# loop
# Inowrocławska
# Głogowska
# LITOMSKA (ZUS)
# loop
# Komandorska
# EPI
# loop
# Arabska
# loop
# GRABISZYŃSKA (Cmentarz)
# Aleja Pracy
# Fiołkowa
# Hutmen
# FAT
# Ostrowskiego
# ROD Oświata
# Wiejska
# Wrocławski Park Technologiczny
# loop
# 8 Maja
# SĘPOLNO
# loop
# Szczepin
# Niedźwiedzia
# loop
# FAT
# Bzowa (Centrum Historii Zajezdnia)
# loop
# loop
# GRABISZYŃSKA (Cmentarz II)
# GRABISZYŃSKA (Cmentarz)
# Solskiego
# OPORÓW
# loop
# Katedra
# Wyszyńskiego
# pl. Bema
# Górnickiego
# Świętokrzyska
# loop
# Babimojska
# Wrocławski Park Przemysłowy
# loop
# Spółdzielcza
# Chełmońskiego
# loop
# Pomorska
# Mosty Pomorskie
# pl. Strzelecki
# Dubois
# Kępa Mieszczańska
# loop
# Braterska
# Radio i Telewizja
# Zimowa
# KRZYKI
# Partynice (tor wyścigów konnych)
# PARK POŁUDNIOWY
# loop
# Narodowe Forum Muzyki
# Mosty Pomorskie
# Świdnicka
# Zamkowa
# PL. JANA PAWŁA II
# Dubois
# Rynek
# loop
# pl. Orląt Lwowskich
# Grabiszyńska
# loop
# Chłodna
# Rymarska
# Modlińska
# loop
# Tramwajowa
# Hala Stulecia
# loop
# rondo Św. Ojca Pio
# loop
# Młodych Techników
# Wrocław Mikołajów (Zachodnia)
# Dolmed
# loop
# Na Niskich Łąkach
# pl. Wróblewskiego
# loop
# BLACHARSKA
# Aleja Wędrowców
# loop
# Strzegomska 148
# Park Biznesu
# loop
# Kochanowskiego
# PL. GRUNWALDZKI
# loop
# Śrubowa
# pl. Strzegomski (Muzeum Współczesne)
# Wrocław Mikołajów (Zachodnia)
# loop
# ZOO
# Kliniki - Politechnika Wrocławska
# Tramwajowa
# Mickiewicza
# loop
# Pl. Hirszfelda
# Arena
# loop
# Wzgórze Partyzantów
# loop
# PL. JANA PAWŁA II
# loop
# Przyjaźni
# KRZYKI
# loop
# Międzyrzecka
# Na Niskich Łąkach
# loop
# Katedra
# PL. GRUNWALDZKI
# loop
# KLECINA
# Os. Przyjaźni
# loop
# BISKUPIN
# Piramowicza (Kampus Biskupin)
# Monte Cassino
# loop
# Godebskiego (AWF Wrocław)
# Monopolowa
# Libelta
# loop
# loop
# Piłsudskiego
# Zaporoska
# EPI
# loop
# Na Szańcach
# Ogród Botaniczny
# Dubois
# Hala Targowa
# loop
# Ślusarska
# loop
# pl. Bema
# Uniwersytet Wrocławski
# Paulińska
# Pomorska
# Rynek
# Hala Targowa
# loop
# GRABISZYŃSKA (Cmentarz)
# FAT
# loop
# Solskiego
# FAT
# GRABISZYŃSKA (Cmentarz II)
# Fiołkowa
# loop
# Kościelna
# Skarbowców
# Sąsiedzka
# loop
# Blizanowicka
# KSIĘŻE MAŁE
# loop
# Rynek
# Pomorska
# loop
# Wrocław Mikołajów (Zachodnia)
# Małopanewska
# Głogowska
# loop
# Przyjaźni
# Husarska
# Hippiczna
# Biskupice Podg. LG Electronics
# KRZYKI
# Bielany Wrocławskie - Makro
# loop
# PL. GRUNWALDZKI
# Prusa
# Górnickiego
# Grunwaldzka
# loop
# loop
# Nowodworska
# Babimojska
# Otyńska
# loop
# Fabryczna
# Wrocławski Park Przemysłowy
# loop
# pl. Strzegomski (Muzeum Współczesne)
# Niedźwiedzia
# Dolmed
# loop
# Ogród Botaniczny
# Damrota
# Prusa
# Nowowiejska
# loop
# Spółdzielcza
# BARTOSZOWICE
# loop
# Nowy Dom
# Międzyrzecka
# loop
# Starodworska
# Księska
# loop
# KROMERA
# loop
# Otyńska
# Uniwersytet Dolnośląski DSW
# loop
# Aleja Pracy
# Krucza (Mielecka)
# Kolbuszowska (Stadion)
# loop
# PL. GRUNWALDZKI
# Śniadeckich
# Grunwaldzka
# Chopina
# Bujwida
# loop
# WAŁBRZYSKA
# KLECINA
# KLECINA (Stacja kolejowa)
# loop
# Niedźwiedzia
# Kwiska
# loop
# loop
# Strzegomska (krzyżówka)
# Strzegomska 148
# MUCHOBÓR MAŁY (Stacja kolejowa)
# Szkocka
# loop
# skwer Krasińskiego
# GALERIA DOMINIKAŃSKA
# loop
# Sąsiedzka
# Przyjaźni
# loop
# Kochanowskiego
# Karłowicza
# loop
# Ogród Botaniczny
# Piastowska
# loop
# loop
# Wrocław Szczepin
# Kępa Mieszczańska
# loop
# Strzegomska 148
# Fabryczna
# loop
# Krucza
# Arkady (Capitol)
# Komandorska
# loop
# Piastowska
# Wyszyńskiego
# loop
# Wrocławski Park Technologiczny
# FAT
# loop
# Karłowicza
# 8 Maja
# Moniuszki
# loop
# loop
# Marchewkowa
# Kościelna
# Marcepanowa
# Połabian
# Wiejska
# loop
# loop
# Chopina
# Stadion Olimpijski
# loop
# Inżynierska
# Krucza
# Kolbuszowska (Stadion)
# loop
# Małopanewska
# DH Astra
# Kolista
# Milenijna (Hala Orbita)
# Wejherowska (Hala Orbita)
# Na Ostatnim Groszu
# Wrocławski Park Technologiczny
# loop
# GIEŁDOWA (Centrum Hurtu)
# WAŁBRZYSKA
# Morelowskiego
# loop
# SĘPOLNO
# Kolumba
# Volvo
# Ceglana
# loop
# Jedności Narodowej
# pl. Bema
# loop
# Końcowa
# FAT
# loop
# loop
# Rogowska (P+R)
# Nowodworska
# Chociebuska (C. K. Nowy Pafawag)
# Strzegomska (krzyżówka)
# loop
# KLECINA
# Braterska
# loop
# Długa (ogrody działkowe)
# Michalczyka
# Szczepin
# loop
# Szkocka
# ROD Oświata
# FAT
# Wejherowska (Hala Orbita)
# Kwiska
# loop
# Orla
# KRZYKI
# loop
# Wiejska
# Morelowskiego
# loop
# Wrocław Popowice (17.południk)
# Wrocław Szczepin
# loop
# Marchewkowa
# Morelowskiego
# loop
# Piastowska
# Kochanowskiego
# loop
# Słowiańska
# Na Szańcach
# Nowowiejska
# loop
# Monopolowa
# Magellana
# Volvo
# loop
# Opatowicka nr 59
# Bierdzany
# loop
# Mickiewicza
# 8 Maja
# loop
# Dembowskiego (Kosiby)
# Okrzei
# loop
# Mokry Dwór - Starodworska
# Blizanowicka
# loop
# Rynek
# loop
# loop
# loop
# Parafialna
# Ołtaszyn
# loop
# OPORÓW
# GRABISZYŃSKA (Cmentarz)
# loop
# Krzemieniecka
# Ostrowskiego
# loop
# Kolumba
# Swojczyce
# loop
# Kliniki - Politechnika Wrocławska
# Park Szczytnicki
# Witelona
# loop
# MOKRY DWÓR
# Starodworska
# loop
# Adamieckiego
# GIEŁDOWA (Centrum Hurtu)
# Marchewkowa
# loop
# Wyszyńskiego
# Słowiańska
# Jedności Narodowej
# Daszyńskiego
# loop
# Partyzantów
# Monte Cassino
# loop
# Dubois
# DWORZEC NADODRZE
# loop
# Rogowska (ogrody działkowe)
# Strzegomska (krzyżówka)
# MIŃSKA (Rondo Rotm. Pileckiego)
# loop
# Śrubowa
# loop
# Gądowianka
# Nowodworska
# Wrocławski Park Technologiczny
# loop
# loop
# Pomorska
# Kleczkowska
# Kępa Mieszczańska
# loop
# loop
# Partynice (tor wyścigów konnych)
# PARK POŁUDNIOWY
# loop
# Chachaja
# Tyniecka
# Wiejska
# TYNIECKA (pętla)
# Mokronos Dolny - Parkowa/Stawowa
# loop
# Mosty Warszawskie
# Berenta
# Grudziądzka
# Kwidzyńska
# Kromera (Czajkowskiego)
# Kętrzyńska
# KROMERA
# loop
# loop
# Trawowa
# Końcowa
# loop
# Wrocław Szczepin
# loop
# Mokry Dwór - Starodworska
# loop
# Okrzei
# Libelta
# Bacciarellego
# Spółdzielcza
# loop
# Milenijna (Hala Orbita)
# Gądowianka
# Kwiska
# Orlińskiego
# loop
# Opatowicka nr 85
# Nowy Dom
# loop
# Magellana
# Mikołowska
# Miłoszycka
# Swojczyce
# Wilczyce - Wilczycka (Stary Młyn)
# loop
# Park Popowicki
# Długa (ogrody działkowe)
# loop
# Kochanowskiego
# Zacisze
# Moniuszki
# loop
# Awicenny (Poczta Polska)
# Jordanowska
# Awicenny
# loop
# Kwiska
# Park Zachodni
# Kolista
# loop
# DWORZEC NADODRZE
# Słowiańska
# Trzebnicka
# Paulińska
# Kleczkowska
# loop
# Na Ostatnim Groszu
# Nowodworska
# Szkocka
# loop
# pl. Strzelecki
# Bałtycka
# most Osobowicki
# PL. STASZICA
# loop
# Inżynierska
# Krucza (Mielecka)
# loop
# Ołtaszyn
# ROD Storczyk
# loop
# Monte Cassino
# SĘPOLNO
# Bacciarellego
# loop
# Płaska
# Rogowska (P+R)
# Tyrmanda
# loop
# loop
# Swojczyce
# Niedziałkowskiego
# loop
# OPATOWICE
# Opatowicka nr 59
# loop
# Drzewieckiego
# Na Ostatnim Groszu
# loop
# Białowieska
# Wrocław Popowice (17.południk)
# Port Popowice
# loop
# Nowowiejska
# DWORZEC NADODRZE
# Zajezdnia OŁBIN
# loop
# Stanisławowska (W.K. Formaty)
# Krzemieniecka
# Awicenny (Stacja kolejowa)
# loop
# Kolista
# Port Popowice
# Kwiska
# Milenijna (Hala Orbita)
# loop
# Śniadeckich
# Kwidzyńska
# loop
# Awicenny (Stacja kolejowa)
# Chachaja
# loop
# KROMERA
# pl. Daniłowskiego
# Kasprowicza
# loop
# Port Popowice
# Park Popowicki
# loop
# Mosty Warszawskie
# Nowowiejska
# Słonimskiego
# loop
# Hynka
# Orlińskiego
# loop
# Mikołowska
# Zagrodnicza
# loop
# Opatowicka nr 127
# Opatowicka nr 85
# loop
# loop
# DH Astra
# Bajana
# Szybowcowa
# loop
# Zagłoby
# MIŃSKA (Rondo Rotm. Pileckiego)
# loop
# Kutrzeby
# Wysoka
# loop
# Muchobór Wielki
# Trawowa
# Awicenny (Stacja kolejowa)
# loop
# Kochanowskiego
# loop
# Awicenny (Poczta Polska)
# Stanisławowska (W.K. Formaty)
# Awicenny
# Trawowa
# loop
# Park Zachodni
# Metalowców
# loop
# Rogowska (Ośrodek sportu)
# Strzegomska (krzyżówka)
# Hermanowska
# loop
# Bystrzycka
# Drzewieckiego
# loop
# Wyszyńskiego
# KROMERA
# Daszyńskiego
# loop
# Muchobór Wielki (Roślinna)
# Stanisławowska (W.K. Formaty)
# Gagarina
# loop
# Zalewowa
# OPATOWICE
# loop
# Wejherowska (Hala Orbita)
# Białowieska
# Park Popowicki
# loop
# DWORZEC NADODRZE
# Broniewskiego
# KARŁOWICE
# loop
# ROD Storczyk
# Wysoka - Chabrowa
# Wysoka - Lipowa
# loop
# Wysoka - Radosna
# rondo Św. Ojca Pio
# loop
# Niedziałkowskiego
# Kmieca
# loop
# Przybyły
# Płaska
# loop
# Kleczkowska
# Łużycka
# Serbska (C.K. Agora)
# Bałtycka
# loop
# KUŹNIKI (Stacja kolejowa)
# Hynka
# Bulwar Dedala
# loop
# loop
# Zagrodnicza
# Smocza
# loop
# KROMERA
# Grudziądzka
# loop
# Zacisze
# Brücknera
# Gęsia
# Kętrzyńska
# KROMERA
# loop
# Tyrmanda
# loop
# Budziszyńska
# Rogowska (P+R)
# loop
# OSOBOWICKA (Cmentarz II)
# most Osobowicki
# Łużycka
# loop
# MIŃSKA (Rondo Rotm. Pileckiego)
# Zagony
# loop
# Wysoka
# Wysoka - Radosna
# loop
# Wysoka - Chabrowa
# Wysoka - osiedle
# Ślęza - autostrada
# loop
# Trestno - świetlica
# Opatowicka nr 127
# WOJNÓW (pętla)
# loop
# Przybyszewskiego
# Berenta
# Kasprowicza
# loop
# Zemska
# Rogowska (ogrody działkowe)
# loop
# Brücknera
# Kromera (Czajkowskiego)
# loop
# Chociebuska (C. K. Nowy Pafawag)
# KUŹNIKI
# Rogowska (Ośrodek sportu)
# loop
# KUŹNIKI
# Bystrzycka
# loop
# PILCZYCKA (Anima)
# Kwiska
# Wejherowska (Hala Orbita)
# Modra
# Milenijna (Hala Orbita)
# Wiślańska
# DH Astra
# KOZANÓW
# loop
# Bajana
# PILCZYCE
# Metalowców
# Rękodzielnicza
# Szybowcowa
# METALOWCÓW (Ośrodek sportu)
# loop
# Jordanowska
# Cesarzowice skrz.
# Mokronos Dolny - Stawowa/Szczęśliwa
# loop
# DWORZEC NADODRZE
# loop
# Czajkowskiego
# loop
# Graniczna
# Zagłoby
# loop
# Kmieca
# Strumykowa
# loop
# loop
# Trestno - kościół
# Zalewowa
# loop
# Muchobór Wielki
# Muchobór Wielki (Roślinna)
# Gagarina
# loop
# most Osobowicki
# Różanka
# OSOBOWICKA (Cmentarz II)
# Serbska (C.K. Agora)
# loop
# KOSZAROWA (Uniwersytet)
# Koszarowa
# loop
# Skarżyńskiego
# Przybyły
# loop
# Hermanowska
# KUŹNIKI (Stacja kolejowa)
# Kołobrzeska
# KUŹNIKI
# METALOWCÓW (Ośrodek sportu)
# loop
# loop
# Mokronos Górny - Wrocławska/Gwarna
# Mokronos Dolny - Parkowa/Stawowa
# loop
# loop
# Metalowców
# Tarczyński Arena (Lotnicza)
# Królewiecka
# PILCZYCE
# loop
# Modra
# Kolista
# loop
# Łużycka
# Bezpieczna
# loop
# Smocza
# Wojnów
# loop
# TRESTNO (pętla)
# Trestno - świetlica
# loop
# Park Tysiąclecia
# Budziszyńska
# loop
# pl. Bema
# loop
# Pola
# Bałtycka
# Kamieńskiego
# Trzebnicka
# Zakładowa
# loop
# Psie Pole
# Kwidzyńska
# Grudziądzka
# C.H. Korona
# Olsztyńska
# loop
# loop
# Wejherowska (Hala Orbita)
# most Milenijny
# Kolista
# Na Ostatnim Groszu
# DH Astra
# loop
# Swojczyce
# Gospodarska
# loop
# Górnicza
# PILCZYCKA (Anima)
# Kozanowska
# Kolista
# loop
# Łużycka
# OSOBOWICKA (Cmentarz)
# Serbska (C.K. Agora)
# loop
# Wrocław Nowy Dwór (P+R)
# Zemska
# loop
# loop
# Wrocław Nowy Dwór (P+R)
# Chociebuska (C. K. Nowy Pafawag)
# Hermanowska
# Strzegomska (krzyżówka)
# loop
# Zarembowicza
# Graniczna
# Graniczna (Strachowicka)
# loop
# loop
# Trestno - kościół
# BLIZANOWICE
# loop
# Strumykowa
# WOJNÓW (pętla)
# loop
# Monte Cassino
# BARTOSZOWICE
# Libelta
# loop
# Bałtycka
# Paprotna
# Różanka
# Bałtycka (szkoła)
# loop
# loop
# Miłoszycka
# Ceglana
# loop
# Gospodarska
# Kowalska
# Kowalska I
# Volvo
# Monopolowa
# loop
# Dworska
# Modra
# KOZANÓW (Dokerska)
# Rękodzielnicza
# KOZANÓW
# loop
# KOSZAROWA (Szpital)
# loop
# WAŁBRZYSKA
# Słoneczna
# loop
# Stadion Olimpijski
# Śniadeckich
# loop
# OSOBOWICKA (Cmentarz II)
# most Milenijny
# loop
# Wojnów
# Zalewowa
# loop
# Park Tysiąclecia
# Kołobrzeska
# Rogowska (Ośrodek sportu)
# Wrocław Nowy Dwór (P+R)
# loop
# Strachowice General Aviation
# loop
# Milenijna (Hala Orbita)
# Obornicka (Obwodnica)
# most Milenijny
# OSOBOWICE
# OSOBOWICKA (Cmentarz)
# loop
# Bystrzycka
# Szybowcowa
# loop
# Trzebnicka
# loop
# pl. Daniłowskiego
# loop
# Broniewskiego
# Kępińska
# Mochnackiego
# Bałtycka
# loop
# pl. Daniłowskiego
# Syrokomli
# Berenta
# loop
# loop
# Smolec - Wrocławska
# Mokronos Dolny - Stawowa/Szczęśliwa
# loop
# Obornicka (Wołowska)
# Zajezdnia Obornicka
# Irysowa
# loop
# Graniczna (Strachowicka)
# Skarżyńskiego
# loop
# Marcepanowa
# Połabian
# loop
# Bacciarellego
# BISKUPIN
# loop
# TARCZYŃSKI ARENA (Królewiecka)
# Górnicza
# loop
# Kowalska I
# Tczewska
# Ceglana
# Volvo
# loop
# Modra
# KOZANÓW (Dokerska)
# loop
# Kamieńskiego
# Wołowska
# loop
# Słoneczna
# C.H. Aleja Bielany
# ROD Bielany
# Biskupice Podg. LG Electronics
# WAŁBRZYSKA
# Kwiatkowskiego
# loop
# Bulwar Dedala
# Bajana
# Metalowców
# loop
# Rdestowa
# Zarembowicza
# Skarżyńskiego
# loop
# Kozanowska
# Górnicza
# KOZANÓW
# Modra
# loop
# Kwidzyńska
# KROMERA
# loop
# Psie Pole (Rondo Lotników Polskich)
# Brücknera
# Zielna
# loop
# Dworska
# Królewiecka
# Maślicka (Osiedle)
# TARCZYŃSKI ARENA (Królewiecka)
# loop
# PILCZYCE
# Glinianki
# loop
# Kowalska
# Działdowska
# loop
# Dzielna
# Kolista
# loop
# Kępińska
# POŚWIĘTNE
# loop
# loop
# Broniewskiego
# Bezpieczna
# Kleczkowska
# most Osobowicki
# Mochnackiego
# loop
# Bałtycka
# loop
# Zielna
# C.H. Korona
# Brücknera
# loop
# Tczewska
# Kowale (Stacja kolejowa)
# KOWALE
# loop
# KOZANÓW
# Wiślańska
# loop
# Tarczyński Arena (Lotnicza)
# Aleja Architektów
# loop
# Jutrosińska
# Kamieńskiego
# Gąsiorowskiego
# loop
# Wołowska
# Zajezdnia Obornicka
# Żmigrodzka (Obwodnica)
# loop
# Syrokomli
# Broniewskiego
# loop
# Odwiedzone węzły: 436, odwiedzone krawędzie: 1299
# [(145,
#   datetime.datetime(2025, 1, 1, 12, 2),
#   datetime.datetime(2025, 1, 1, 12, 3),
#   'Vivaldiego',
#   51.04509727,
#   17.06086879),
#  (145,
#   datetime.datetime(2025, 1, 1, 12, 3),
#   datetime.datetime(2025, 1, 1, 12, 5),
#   'Kajdasza',
#   51.05009367,
#   17.05910045),
#  (145,
#   datetime.datetime(2025, 1, 1, 12, 5),
#   datetime.datetime(2025, 1, 1, 12, 7),
#   'Jagodzińska',
#   51.05422485,
#   17.05798773),
#  (145,
#   datetime.datetime(2025, 1, 1, 12, 7),
#   datetime.datetime(2025, 1, 1, 12, 8),
#   'Malinowskiego',
#   51.05919701,
#   17.05650629),
#  (145,
#   datetime.datetime(2025, 1, 1, 12, 8),
#   datetime.datetime(2025, 1, 1, 12, 9),
#   'Konduktorska',
#   51.06290665,
#   17.05554594),
#  (145,
#   datetime.datetime(2025, 1, 1, 12, 9),
#   datetime.datetime(2025, 1, 1, 12, 10),
#   'Buforowa-Rondo',
#   51.067443,
#   17.054504),
#  (145,
#   datetime.datetime(2025, 1, 1, 12, 10),
#   datetime.datetime(2025, 1, 1, 12, 11),
#   'BARDZKA (Cmentarz)',
#   51.07064457,
#   17.05385413),
#  (145,
#   datetime.datetime(2025, 1, 1, 12, 11),
#   datetime.datetime(2025, 1, 1, 12, 13),
#   'GAJ - pętla',
#   51.07306135,
#   17.0531783),
#  (145,
#   datetime.datetime(2025, 1, 1, 12, 13),
#   datetime.datetime(2025, 1, 1, 12, 14),
#   'Świeradowska',
#   51.07678179,
#   17.05099042),
#  (145,
#   datetime.datetime(2025, 1, 1, 12, 14),
#   datetime.datetime(2025, 1, 1, 12, 16),
#   'GAJ',
#   51.07704664,
#   17.04623752),
#  (145,
#   datetime.datetime(2025, 1, 1, 12, 16),
#   datetime.datetime(2025, 1, 1, 12, 18),
#   'Działkowa',
#   51.07715659,
#   17.03977587),
#  (145,
#   datetime.datetime(2025, 1, 1, 12, 18),
#   datetime.datetime(2025, 1, 1, 12, 20),
#   'ROD Bajki',
#   51.0783962,
#   17.03423151),
#  (145,
#   datetime.datetime(2025, 1, 1, 12, 20),
#   datetime.datetime(2025, 1, 1, 12, 21),
#   'Śliczna',
#   51.08389472,
#   17.03529441),
#  (145,
#   datetime.datetime(2025, 1, 1, 12, 21),
#   datetime.datetime(2025, 1, 1, 12, 23),
#   'Borowska (Aquapark)',
#   51.08570546,
#   17.03538249),
#  (145,
#   datetime.datetime(2025, 1, 1, 12, 23),
#   datetime.datetime(2025, 1, 1, 12, 27),
#   'DWORZEC AUTOBUSOWY',
#   51.08929574,
#   17.03414067),
#  (145,
#   datetime.datetime(2025, 1, 1, 12, 27),
#   datetime.datetime(2025, 1, 1, 12, 30),
#   'DWORZEC GŁÓWNY',
#   51.09657455,
#   17.03298047),
#  (145,
#   datetime.datetime(2025, 1, 1, 12, 30),
#   datetime.datetime(2025, 1, 1, 12, 33),
#   'Dworzec Główny (Dworcowa)',
#   51.09960174,
#   17.03540039),
#  (145,
#   datetime.datetime(2025, 1, 1, 12, 33),
#   datetime.datetime(2025, 1, 1, 12, 35),
#   'skwer Krasińskiego',
#   51.10114919,
#   17.04001736),
#  (145,
#   datetime.datetime(2025, 1, 1, 12, 35),
#   datetime.datetime(2025, 1, 1, 12, 36),
#   'Krasińskiego',
#   51.103441,
#   17.04226),
#  ('A',
#   datetime.datetime(2025, 1, 1, 12, 38),
#   datetime.datetime(2025, 1, 1, 12, 41),
#   'Urząd Wojewódzki (Muzeum Narodowe)',
#   51.10585896,
#   17.04334082),
#  ('A',
#   datetime.datetime(2025, 1, 1, 12, 41),
#   datetime.datetime(2025, 1, 1, 12, 43),
#   'Katedra',
#   51.11044991,
#   17.04858192),
#  ('A',
#   datetime.datetime(2025, 1, 1, 12, 43),
#   datetime.datetime(2025, 1, 1, 12, 45),
#   'Ogród Botaniczny',
#   51.11419938,
#   17.05079812),
#  ('A',
#   datetime.datetime(2025, 1, 1, 12, 45),
#   datetime.datetime(2025, 1, 1, 12, 47),
#   'Wyszyńskiego',
#   51.11715674,
#   17.05147222),
#  ('A',
#   datetime.datetime(2025, 1, 1, 12, 47),
#   datetime.datetime(2025, 1, 1, 12, 48),
#   'Damrota',
#   51.1227988,
#   17.0528858),
#  ('A',
#   datetime.datetime(2025, 1, 1, 12, 48),
#   datetime.datetime(2025, 1, 1, 12, 53),
#   'KROMERA',
#   51.12648854,
#   17.0548761),
#  ('N',
#   datetime.datetime(2025, 1, 1, 12, 55),
#   datetime.datetime(2025, 1, 1, 12, 57),
#   'Kromera (Czajkowskiego)',
#   51.13222406,
#   17.06514893),
#  ('N',
#   datetime.datetime(2025, 1, 1, 12, 57),
#   datetime.datetime(2025, 1, 1, 12, 58),
#   'Grudziądzka',
#   51.13631426,
#   17.07044445),
#  ('N',
#   datetime.datetime(2025, 1, 1, 12, 58),
#   datetime.datetime(2025, 1, 1, 13, 0),
#   'Brücknera',
#   51.13794927,
#   17.07506203),
#  ('N',
#   datetime.datetime(2025, 1, 1, 13, 0),
#   datetime.datetime(2025, 1, 1, 13, 4),
#   'Psie Pole',
#   51.13916827,
#   17.08080603),
#  ('N',
#   datetime.datetime(2025, 1, 1, 13, 4),
#   datetime.datetime(2025, 1, 1, 13, 5),
#   'Psie Pole (Rondo Lotników Polskich)',
#   51.14555136,
#   17.1109989)]

# %%
def initial_solution_nn(graph, start, stops):

    def calculate_distance(stop1, stop2):
        c1 = extract_first_connection(stop1, graph)
        c2 = extract_first_connection(stop2, graph)
        return euclidean_distance(c1.start_latitude, c2.start_latitude, 
                                  c1.start_longitude, c2.start_longitude)
    path = [start]
    unvisited = set(stops) - {start}

    current_stop = start
    while unvisited:
        next_stop = min(unvisited, key=lambda stop: calculate_distance(current_stop, stop))
        path.append(next_stop)
        unvisited.remove(next_stop)
        current_stop = next_stop

    path.append(start)
    cordinates = [(extract_first_connection(x, graph).start_latitude, extract_first_connection(x, graph).start_longitude) for x in path]
    return (path, cordinates)

# %%
print(extract_first_connection("Działkowa", graph))
# Out:
# Connection(K, 06:42:00 -> 06:44:00, GAJ)

# %%
import folium
from IPython.display import display

path, cords = initial_solution_nn(graph, "Iwiny - rondo", 
                          ["Świeradowska", "PL. GRUNWALDZKI", "Działkowa", "PARK POŁUDNIOWY", 
                           "Psie Pole (Rondo Lotników Polskich)", "KOZANÓW", "Irysowa"])

m = folium.Map(location=cords[0], zoom_start=12)

for i, coord in enumerate(cords):
    folium.Marker(coord, tooltip=f"Przystanek {i+1}").add_to(m)

path

# folium.PolyLine(cords, color="blue", weight=5, opacity=0.7).add_to(m)
# display(m)
# Out:
# ['Iwiny - rondo',
#  'Świeradowska',
#  'Działkowa',
#  'PARK POŁUDNIOWY',
#  'PL. GRUNWALDZKI',
#  'Irysowa',
#  'KOZANÓW',
#  'Psie Pole (Rondo Lotników Polskich)',
#  'Iwiny - rondo']

# %%
def evaluate_solution(graph, path, departure_time):
    total_time = 0
    total_route = []

    current_time = datetime.strptime(departure_time, '%H:%M:%S')
    for i in range(len(path) - 1):
        

        connection_time, route = astar(path[i], path[i+1], current_time.strftime('%H:%M:%S'), graph, zero_heuristic)
        total_time += connection_time
        total_route += route
        current_time += timedelta(minutes=connection_time)

    return total_time, total_route
        

path, cords = initial_solution_nn(graph, "Iwiny - rondo", 
                          ["Świeradowska", "PL. GRUNWALDZKI", "Działkowa", "PARK POŁUDNIOWY", 
                           "Psie Pole (Rondo Lotników Polskich)", "KOZANÓW", "Irysowa"])

evaluate_solution(graph, path, "11:25:00")
# Out:
# (255.0,
#  [Connection(110, 11:25:00 -> 11:26:00, Vivaldiego),
#   Connection(110, 11:26:00 -> 11:28:00, Kajdasza),
#   Connection(110, 11:28:00 -> 11:30:00, Jagodzińska),
#   Connection(110, 11:30:00 -> 11:31:00, Malinowskiego),
#   Connection(110, 11:31:00 -> 11:32:00, Konduktorska),
#   Connection(110, 11:32:00 -> 11:33:00, Buforowa-Rondo),
#   Connection(110, 11:33:00 -> 11:34:00, BARDZKA (Cmentarz)),
#   Connection(110, 11:34:00 -> 11:35:00, Morwowa),
#   Connection(21, 11:41:00 -> 11:42:00, Świeradowska),
#   Connection(21, 11:42:00 -> 11:44:00, GAJ),
#   Connection(145, 11:46:00 -> 11:48:00, Działkowa),
#   Connection(145, 11:48:00 -> 11:50:00, ROD Bajki),
#   Connection(145, 11:50:00 -> 11:51:00, Śliczna),
#   Connection(143, 11:54:00 -> 11:57:00, Uniwersytet Ekonomiczny),
#   Connection(9, 12:00:00 -> 12:02:00, Wiśniowa),
#   Connection(9, 12:02:00 -> 12:03:00, Jaworowa),
#   Connection(9, 12:03:00 -> 12:04:00, Weigla (Szpital)),
#   Connection(9, 12:04:00 -> 12:05:00, Pułtuska),
#   Connection(9, 12:05:00 -> 12:06:00, PARK POŁUDNIOWY),
#   Connection(9, 12:08:00 -> 12:09:00, Pułtuska),
#   Connection(9, 12:09:00 -> 12:10:00, Weigla (Szpital)),
#   Connection(9, 12:10:00 -> 12:11:00, Jaworowa),
#   Connection(9, 12:11:00 -> 12:12:00, Wiśniowa),
#   Connection(9, 12:12:00 -> 12:14:00, Uniwersytet Ekonomiczny),
#   Connection(9, 12:14:00 -> 12:15:00, Sanocka),
#   Connection(9, 12:15:00 -> 12:17:00, DWORZEC AUTOBUSOWY),
#   Connection(9, 12:17:00 -> 12:19:00, DWORZEC GŁÓWNY),
#   Connection(9, 12:19:00 -> 12:21:00, Wzgórze Partyzantów),
#   Connection(9, 12:21:00 -> 12:24:00, GALERIA DOMINIKAŃSKA),
#   Connection(13, 12:29:00 -> 12:32:00, Urząd Wojewódzki (Impart)),
#   Connection(13, 12:32:00 -> 12:34:00, most Grunwaldzki),
#   Connection(13, 12:34:00 -> 12:36:00, PL. GRUNWALDZKI),
#   Connection(19, 12:36:00 -> 12:38:00, Piastowska),
#   Connection(1, 12:40:00 -> 12:42:00, Prusa),
#   Connection(1, 12:42:00 -> 12:43:00, Wyszyńskiego),
#   Connection(1, 12:43:00 -> 12:45:00, Nowowiejska),
#   Connection(1, 12:45:00 -> 12:47:00, Słowiańska),
#   Connection(1, 12:47:00 -> 12:49:00, DWORZEC NADODRZE),
#   Connection(1, 12:50:00 -> 12:52:00, Trzebnicka),
#   Connection(1, 12:52:00 -> 12:56:00, Broniewskiego),
#   Connection(111, 13:00:00 -> 13:02:00, Bałtycka),
#   Connection(111, 13:02:00 -> 13:04:00, Bezpieczna),
#   Connection(111, 13:04:00 -> 13:05:00, Paprotna),
#   Connection(111, 13:05:00 -> 13:06:00, Irysowa),
#   Connection(105, 13:07:00 -> 13:08:00, Paprotna),
#   Connection(105, 13:08:00 -> 13:09:00, Obornicka (Wołowska)),
#   Connection(105, 13:09:00 -> 13:10:00, Bezpieczna),
#   Connection(119, 13:12:00 -> 13:13:00, Różanka),
#   Connection(119, 13:13:00 -> 13:14:00, Łużycka),
#   Connection(119, 13:14:00 -> 13:15:00, OSOBOWICKA (Cmentarz II)),
#   Connection(119, 13:15:00 -> 13:16:00, OSOBOWICKA (Cmentarz)),
#   Connection(119, 13:16:00 -> 13:17:00, most Milenijny),
#   Connection(119, 13:18:00 -> 13:19:00, Milenijna (Hala Orbita)),
#   Connection(119, 13:19:00 -> 13:22:00, Wejherowska (Hala Orbita)),
#   Connection(19, 13:27:00 -> 13:30:00, Kolista),
#   Connection(102, 13:33:00 -> 13:34:00, Wiślańska),
#   Connection(102, 13:34:00 -> 13:35:00, Dzielna),
#   Connection(102, 13:35:00 -> 13:36:00, KOZANÓW),
#   Connection(104, 13:36:00 -> 13:37:00, Dzielna),
#   Connection(104, 13:37:00 -> 13:38:00, Wiślańska),
#   Connection(104, 13:38:00 -> 13:40:00, Kolista),
#   Connection(127, 13:42:00 -> 13:45:00, Wejherowska (Hala Orbita)),
#   Connection(104, 13:47:00 -> 13:49:00, Milenijna (Hala Orbita)),
#   Connection(104, 13:49:00 -> 13:50:00, most Milenijny),
#   Connection(104, 13:52:00 -> 13:53:00, OSOBOWICE),
#   Connection(118, 13:55:00 -> 13:57:00, OSOBOWICKA (Cmentarz)),
#   Connection(118, 13:57:00 -> 13:58:00, OSOBOWICKA (Cmentarz II)),
#   Connection(118, 13:58:00 -> 14:00:00, Łużycka),
#   Connection(118, 14:00:00 -> 14:01:00, Różanka),
#   Connection(118, 14:01:00 -> 14:03:00, Bezpieczna),
#   Connection(118, 14:03:00 -> 14:04:00, Bałtycka (szkoła)),
#   Connection(118, 14:04:00 -> 14:05:00, Bałtycka),
#   Connection(118, 14:05:00 -> 14:08:00, Broniewskiego),
#   Connection(118, 14:08:00 -> 14:09:00, Pola),
#   Connection(118, 14:09:00 -> 14:10:00, Syrokomli),
#   Connection(118, 14:10:00 -> 14:11:00, Kasprowicza),
#   Connection(118, 14:11:00 -> 14:13:00, pl. Daniłowskiego),
#   Connection(118, 14:13:00 -> 14:14:00, Berenta),
#   Connection(118, 14:14:00 -> 14:19:00, KROMERA),
#   Connection(118, 14:19:00 -> 14:23:00, Kwidzyńska),
#   Connection(118, 14:23:00 -> 14:25:00, Brücknera),
#   Connection(128, 14:27:00 -> 14:29:00, C.H. Korona),
#   Connection(128, 14:29:00 -> 14:31:00, Zielna),
#   Connection(128, 14:31:00 -> 14:32:00, Psie Pole),
#   Connection(128, 14:32:00 -> 14:34:00, Psie Pole (Rondo Lotników Polskich)),
#   Connection(130, 14:34:00 -> 14:35:00, Psie Pole),
#   Connection(130, 14:35:00 -> 14:36:00, Zielna),
#   Connection(130, 14:36:00 -> 14:38:00, C.H. Korona),
#   Connection(130, 14:39:00 -> 14:41:00, Brücknera),
#   Connection(151, 14:45:00 -> 14:47:00, Kwidzyńska),
#   Connection(151, 14:47:00 -> 14:48:00, Zacisze),
#   Connection(151, 14:48:00 -> 14:49:00, Śniadeckich),
#   Connection(151, 14:49:00 -> 14:52:00, Kochanowskiego),
#   Connection(9, 14:55:00 -> 14:56:00, Chopina),
#   Connection(9, 14:56:00 -> 14:57:00, Karłowicza),
#   Connection(9, 14:57:00 -> 14:58:00, Stadion Olimpijski),
#   Connection(9, 14:58:00 -> 14:59:00, 8 Maja),
#   Connection(143, 15:03:00 -> 15:05:00, Dembowskiego (Kosiby)),
#   Connection(143, 15:05:00 -> 15:06:00, Chełmońskiego),
#   Connection(143, 15:06:00 -> 15:07:00, Biegasa),
#   Connection(143, 15:07:00 -> 15:09:00, Międzyrzecka),
#   Connection(143, 15:09:00 -> 15:11:00, Armii Krajowej),
#   Connection(143, 15:11:00 -> 15:12:00, Armii Krajowej (Bogedaina)),
#   Connection(143, 15:12:00 -> 15:14:00, Klimasa),
#   Connection(143, 15:14:00 -> 15:15:00, Złotostocka),
#   Connection(143, 15:15:00 -> 15:17:00, GAJ - pętla),
#   Connection(143, 15:17:00 -> 15:19:00, Świeradowska),
#   Connection(143, 15:19:00 -> 15:21:00, Morwowa),
#   Connection(110, 15:25:00 -> 15:26:00, BARDZKA (Cmentarz)),
#   Connection(110, 15:26:00 -> 15:28:00, Buforowa-Rondo),
#   Connection(110, 15:28:00 -> 15:30:00, Konduktorska),
#   Connection(110, 15:30:00 -> 15:32:00, Malinowskiego),
#   Connection(110, 15:32:00 -> 15:34:00, Jagodzińska),
#   Connection(110, 15:34:00 -> 15:36:00, Kajdasza),
#   Connection(110, 15:36:00 -> 15:38:00, Vivaldiego),
#   Connection(110, 15:38:00 -> 15:40:00, Iwiny - rondo)])

# %%
def generate_neighbourhood(path):
    core_path = path[1:-1]
    neighborhood = set()
    
    for i in range(len(core_path) - 1):
        neighbor = core_path.copy()
        neighbor[i], neighbor[i+1] = neighbor[i+1], neighbor[i]
        neighborhood.add(tuple([path[0]] + neighbor + [path[-1]]))
    
    for i in range(len(core_path)):
        for j in range(len(core_path)):
            if i != j:
                neighbor = core_path.copy()
                city = neighbor.pop(i)
                neighbor.insert(j, city)
                neighborhood.add(tuple([path[0]] + neighbor + [path[-1]]))
    
    for start in range(len(core_path)):
        for end in range(start + 1, len(core_path)):
            neighbor = core_path.copy()
            neighbor[start:end+1] = reversed(neighbor[start:end+1])
            neighborhood.add(tuple([path[0]] + neighbor + [path[-1]]))
    
    return [list(sol) for sol in neighborhood]

generate_neighbourhood(path)
# Out:
# [['Iwiny - rondo',
#   'Działkowa',
#   'PARK POŁUDNIOWY',
#   'PL. GRUNWALDZKI',
#   'Irysowa',
#   'KOZANÓW',
#   'Świeradowska',
#   'Psie Pole (Rondo Lotników Polskich)',
#   'Iwiny - rondo'],
#  ['Iwiny - rondo',
#   'Świeradowska',
#   'Działkowa',
#   'PARK POŁUDNIOWY',
#   'PL. GRUNWALDZKI',
#   'KOZANÓW',
#   'Irysowa',
#   'Psie Pole (Rondo Lotników Polskich)',
#   'Iwiny - rondo'],
#  ['Iwiny - rondo',
#   'Działkowa',
#   'PARK POŁUDNIOWY',
#   'PL. GRUNWALDZKI',
#   'Świeradowska',
#   'Irysowa',
#   'KOZANÓW',
#   'Psie Pole (Rondo Lotników Polskich)',
#   'Iwiny - rondo'],
#  ['Iwiny - rondo',
#   'Świeradowska',
#   'Działkowa',
#   'PL. GRUNWALDZKI',
#   'PARK POŁUDNIOWY',
#   'Irysowa',
#   'KOZANÓW',
#   'Psie Pole (Rondo Lotników Polskich)',
#   'Iwiny - rondo'],
#  ['Iwiny - rondo',
#   'Działkowa',
#   'PARK POŁUDNIOWY',
#   'PL. GRUNWALDZKI',
#   'Irysowa',
#   'KOZANÓW',
#   'Psie Pole (Rondo Lotników Polskich)',
#   'Świeradowska',
#   'Iwiny - rondo'],
#  ['Iwiny - rondo',
#   'PL. GRUNWALDZKI',
#   'PARK POŁUDNIOWY',
#   'Działkowa',
#   'Świeradowska',
#   'Irysowa',
#   'KOZANÓW',
#   'Psie Pole (Rondo Lotników Polskich)',
#   'Iwiny - rondo'],
#  ['Iwiny - rondo',
#   'Świeradowska',
#   'Działkowa',
#   'Irysowa',
#   'PL. GRUNWALDZKI',
#   'PARK POŁUDNIOWY',
#   'KOZANÓW',
#   'Psie Pole (Rondo Lotników Polskich)',
#   'Iwiny - rondo'],
#  ['Iwiny - rondo',
#   'Świeradowska',
#   'Działkowa',
#   'PL. GRUNWALDZKI',
#   'Irysowa',
#   'KOZANÓW',
#   'Psie Pole (Rondo Lotników Polskich)',
#   'PARK POŁUDNIOWY',
#   'Iwiny - rondo'],
#  ['Iwiny - rondo',
#   'Świeradowska',
#   'PARK POŁUDNIOWY',
#   'PL. GRUNWALDZKI',
#   'Działkowa',
#   'Irysowa',
#   'KOZANÓW',
#   'Psie Pole (Rondo Lotników Polskich)',
#   'Iwiny - rondo'],
#  ['Iwiny - rondo',
#   'Świeradowska',
#   'Działkowa',
#   'PARK POŁUDNIOWY',
#   'Psie Pole (Rondo Lotników Polskich)',
#   'PL. GRUNWALDZKI',
#   'Irysowa',
#   'KOZANÓW',
#   'Iwiny - rondo'],
#  ['Iwiny - rondo',
#   'Świeradowska',
#   'Irysowa',
#   'Działkowa',
#   'PARK POŁUDNIOWY',
#   'PL. GRUNWALDZKI',
#   'KOZANÓW',
#   'Psie Pole (Rondo Lotników Polskich)',
#   'Iwiny - rondo'],
#  ['Iwiny - rondo',
#   'Świeradowska',
#   'PL. GRUNWALDZKI',
#   'PARK POŁUDNIOWY',
#   'Działkowa',
#   'Irysowa',
#   'KOZANÓW',
#   'Psie Pole (Rondo Lotników Polskich)',
#   'Iwiny - rondo'],
#  ['Iwiny - rondo',
#   'Świeradowska',
#   'Psie Pole (Rondo Lotników Polskich)',
#   'KOZANÓW',
#   'Irysowa',
#   'PL. GRUNWALDZKI',
#   'PARK POŁUDNIOWY',
#   'Działkowa',
#   'Iwiny - rondo'],
#  ['Iwiny - rondo',
#   'PL. GRUNWALDZKI',
#   'Świeradowska',
#   'Działkowa',
#   'PARK POŁUDNIOWY',
#   'Irysowa',
#   'KOZANÓW',
#   'Psie Pole (Rondo Lotników Polskich)',
#   'Iwiny - rondo'],
#  ['Iwiny - rondo',
#   'Świeradowska',
#   'PARK POŁUDNIOWY',
#   'PL. GRUNWALDZKI',
#   'Irysowa',
#   'KOZANÓW',
#   'Działkowa',
#   'Psie Pole (Rondo Lotników Polskich)',
#   'Iwiny - rondo'],
#  ['Iwiny - rondo',
#   'Świeradowska',
#   'Działkowa',
#   'PARK POŁUDNIOWY',
#   'KOZANÓW',
#   'PL. GRUNWALDZKI',
#   'Irysowa',
#   'Psie Pole (Rondo Lotników Polskich)',
#   'Iwiny - rondo'],
#  ['Iwiny - rondo',
#   'Świeradowska',
#   'PARK POŁUDNIOWY',
#   'Działkowa',
#   'PL. GRUNWALDZKI',
#   'Irysowa',
#   'KOZANÓW',
#   'Psie Pole (Rondo Lotników Polskich)',
#   'Iwiny - rondo'],
#  ['Iwiny - rondo',
#   'Świeradowska',
#   'Działkowa',
#   'PL. GRUNWALDZKI',
#   'Irysowa',
#   'KOZANÓW',
#   'PARK POŁUDNIOWY',
#   'Psie Pole (Rondo Lotników Polskich)',
#   'Iwiny - rondo'],
#  ['Iwiny - rondo',
#   'Świeradowska',
#   'Działkowa',
#   'Irysowa',
#   'PARK POŁUDNIOWY',
#   'PL. GRUNWALDZKI',
#   'KOZANÓW',
#   'Psie Pole (Rondo Lotników Polskich)',
#   'Iwiny - rondo'],
#  ['Iwiny - rondo',
#   'Świeradowska',
#   'Działkowa',
#   'PARK POŁUDNIOWY',
#   'KOZANÓW',
#   'Irysowa',
#   'PL. GRUNWALDZKI',
#   'Psie Pole (Rondo Lotników Polskich)',
#   'Iwiny - rondo'],
#  ['Iwiny - rondo',
#   'Świeradowska',
#   'Działkowa',
#   'KOZANÓW',
#   'Irysowa',
#   'PL. GRUNWALDZKI',
#   'PARK POŁUDNIOWY',
#   'Psie Pole (Rondo Lotników Polskich)',
#   'Iwiny - rondo'],
#  ['Iwiny - rondo',
#   'Świeradowska',
#   'Działkowa',
#   'PARK POŁUDNIOWY',
#   'PL. GRUNWALDZKI',
#   'Irysowa',
#   'Psie Pole (Rondo Lotników Polskich)',
#   'KOZANÓW',
#   'Iwiny - rondo'],
#  ['Iwiny - rondo',
#   'Działkowa',
#   'PARK POŁUDNIOWY',
#   'Świeradowska',
#   'PL. GRUNWALDZKI',
#   'Irysowa',
#   'KOZANÓW',
#   'Psie Pole (Rondo Lotników Polskich)',
#   'Iwiny - rondo'],
#  ['Iwiny - rondo',
#   'Świeradowska',
#   'Działkowa',
#   'PARK POŁUDNIOWY',
#   'PL. GRUNWALDZKI',
#   'KOZANÓW',
#   'Psie Pole (Rondo Lotników Polskich)',
#   'Irysowa',
#   'Iwiny - rondo'],
#  ['Iwiny - rondo',
#   'KOZANÓW',
#   'Irysowa',
#   'PL. GRUNWALDZKI',
#   'PARK POŁUDNIOWY',
#   'Działkowa',
#   'Świeradowska',
#   'Psie Pole (Rondo Lotników Polskich)',
#   'Iwiny - rondo'],
#  ['Iwiny - rondo',
#   'Świeradowska',
#   'KOZANÓW',
#   'Irysowa',
#   'PL. GRUNWALDZKI',
#   'PARK POŁUDNIOWY',
#   'Działkowa',
#   'Psie Pole (Rondo Lotników Polskich)',
#   'Iwiny - rondo'],
#  ['Iwiny - rondo',
#   'Świeradowska',
#   'Psie Pole (Rondo Lotników Polskich)',
#   'Działkowa',
#   'PARK POŁUDNIOWY',
#   'PL. GRUNWALDZKI',
#   'Irysowa',
#   'KOZANÓW',
#   'Iwiny - rondo'],
#  ['Iwiny - rondo',
#   'Irysowa',
#   'PL. GRUNWALDZKI',
#   'PARK POŁUDNIOWY',
#   'Działkowa',
#   'Świeradowska',
#   'KOZANÓW',
#   'Psie Pole (Rondo Lotników Polskich)',
#   'Iwiny - rondo'],
#  ['Iwiny - rondo',
#   'Świeradowska',
#   'Działkowa',
#   'PARK POŁUDNIOWY',
#   'Psie Pole (Rondo Lotników Polskich)',
#   'KOZANÓW',
#   'Irysowa',
#   'PL. GRUNWALDZKI',
#   'Iwiny - rondo'],
#  ['Iwiny - rondo',
#   'Świeradowska',
#   'Działkowa',
#   'Psie Pole (Rondo Lotników Polskich)',
#   'KOZANÓW',
#   'Irysowa',
#   'PL. GRUNWALDZKI',
#   'PARK POŁUDNIOWY',
#   'Iwiny - rondo'],
#  ['Iwiny - rondo',
#   'Świeradowska',
#   'Działkowa',
#   'PL. GRUNWALDZKI',
#   'Irysowa',
#   'PARK POŁUDNIOWY',
#   'KOZANÓW',
#   'Psie Pole (Rondo Lotników Polskich)',
#   'Iwiny - rondo'],
#  ['Iwiny - rondo',
#   'PARK POŁUDNIOWY',
#   'Świeradowska',
#   'Działkowa',
#   'PL. GRUNWALDZKI',
#   'Irysowa',
#   'KOZANÓW',
#   'Psie Pole (Rondo Lotników Polskich)',
#   'Iwiny - rondo'],
#  ['Iwiny - rondo',
#   'PARK POŁUDNIOWY',
#   'Działkowa',
#   'Świeradowska',
#   'PL. GRUNWALDZKI',
#   'Irysowa',
#   'KOZANÓW',
#   'Psie Pole (Rondo Lotników Polskich)',
#   'Iwiny - rondo'],
#  ['Iwiny - rondo',
#   'Świeradowska',
#   'Działkowa',
#   'PARK POŁUDNIOWY',
#   'PL. GRUNWALDZKI',
#   'Psie Pole (Rondo Lotników Polskich)',
#   'KOZANÓW',
#   'Irysowa',
#   'Iwiny - rondo'],
#  ['Iwiny - rondo',
#   'Działkowa',
#   'Świeradowska',
#   'PARK POŁUDNIOWY',
#   'PL. GRUNWALDZKI',
#   'Irysowa',
#   'KOZANÓW',
#   'Psie Pole (Rondo Lotników Polskich)',
#   'Iwiny - rondo'],
#  ['Iwiny - rondo',
#   'Świeradowska',
#   'PARK POŁUDNIOWY',
#   'PL. GRUNWALDZKI',
#   'Irysowa',
#   'Działkowa',
#   'KOZANÓW',
#   'Psie Pole (Rondo Lotników Polskich)',
#   'Iwiny - rondo'],
#  ['Iwiny - rondo',
#   'Świeradowska',
#   'PL. GRUNWALDZKI',
#   'Działkowa',
#   'PARK POŁUDNIOWY',
#   'Irysowa',
#   'KOZANÓW',
#   'Psie Pole (Rondo Lotników Polskich)',
#   'Iwiny - rondo'],
#  ['Iwiny - rondo',
#   'Świeradowska',
#   'Irysowa',
#   'PL. GRUNWALDZKI',
#   'PARK POŁUDNIOWY',
#   'Działkowa',
#   'KOZANÓW',
#   'Psie Pole (Rondo Lotników Polskich)',
#   'Iwiny - rondo'],
#  ['Iwiny - rondo',
#   'Irysowa',
#   'Świeradowska',
#   'Działkowa',
#   'PARK POŁUDNIOWY',
#   'PL. GRUNWALDZKI',
#   'KOZANÓW',
#   'Psie Pole (Rondo Lotników Polskich)',
#   'Iwiny - rondo'],
#  ['Iwiny - rondo',
#   'KOZANÓW',
#   'Świeradowska',
#   'Działkowa',
#   'PARK POŁUDNIOWY',
#   'PL. GRUNWALDZKI',
#   'Irysowa',
#   'Psie Pole (Rondo Lotników Polskich)',
#   'Iwiny - rondo'],
#  ['Iwiny - rondo',
#   'Świeradowska',
#   'Działkowa',
#   'PARK POŁUDNIOWY',
#   'Irysowa',
#   'PL. GRUNWALDZKI',
#   'KOZANÓW',
#   'Psie Pole (Rondo Lotników Polskich)',
#   'Iwiny - rondo'],
#  ['Iwiny - rondo',
#   'Świeradowska',
#   'Działkowa',
#   'Psie Pole (Rondo Lotników Polskich)',
#   'PARK POŁUDNIOWY',
#   'PL. GRUNWALDZKI',
#   'Irysowa',
#   'KOZANÓW',
#   'Iwiny - rondo'],
#  ['Iwiny - rondo',
#   'Świeradowska',
#   'Działkowa',
#   'PARK POŁUDNIOWY',
#   'PL. GRUNWALDZKI',
#   'Psie Pole (Rondo Lotników Polskich)',
#   'Irysowa',
#   'KOZANÓW',
#   'Iwiny - rondo'],
#  ['Iwiny - rondo',
#   'Świeradowska',
#   'PARK POŁUDNIOWY',
#   'PL. GRUNWALDZKI',
#   'Irysowa',
#   'KOZANÓW',
#   'Psie Pole (Rondo Lotników Polskich)',
#   'Działkowa',
#   'Iwiny - rondo'],
#  ['Iwiny - rondo',
#   'Psie Pole (Rondo Lotników Polskich)',
#   'Świeradowska',
#   'Działkowa',
#   'PARK POŁUDNIOWY',
#   'PL. GRUNWALDZKI',
#   'Irysowa',
#   'KOZANÓW',
#   'Iwiny - rondo'],
#  ['Iwiny - rondo',
#   'Świeradowska',
#   'Działkowa',
#   'KOZANÓW',
#   'PARK POŁUDNIOWY',
#   'PL. GRUNWALDZKI',
#   'Irysowa',
#   'Psie Pole (Rondo Lotników Polskich)',
#   'Iwiny - rondo'],
#  ['Iwiny - rondo',
#   'Działkowa',
#   'PARK POŁUDNIOWY',
#   'PL. GRUNWALDZKI',
#   'Irysowa',
#   'Świeradowska',
#   'KOZANÓW',
#   'Psie Pole (Rondo Lotników Polskich)',
#   'Iwiny - rondo'],
#  ['Iwiny - rondo',
#   'Świeradowska',
#   'Działkowa',
#   'PARK POŁUDNIOWY',
#   'Irysowa',
#   'KOZANÓW',
#   'Psie Pole (Rondo Lotników Polskich)',
#   'PL. GRUNWALDZKI',
#   'Iwiny - rondo'],
#  ['Iwiny - rondo',
#   'Świeradowska',
#   'KOZANÓW',
#   'Działkowa',
#   'PARK POŁUDNIOWY',
#   'PL. GRUNWALDZKI',
#   'Irysowa',
#   'Psie Pole (Rondo Lotników Polskich)',
#   'Iwiny - rondo'],
#  ['Iwiny - rondo',
#   'Psie Pole (Rondo Lotników Polskich)',
#   'KOZANÓW',
#   'Irysowa',
#   'PL. GRUNWALDZKI',
#   'PARK POŁUDNIOWY',
#   'Działkowa',
#   'Świeradowska',
#   'Iwiny - rondo'],
#  ['Iwiny - rondo',
#   'Świeradowska',
#   'Działkowa',
#   'PARK POŁUDNIOWY',
#   'Irysowa',
#   'KOZANÓW',
#   'PL. GRUNWALDZKI',
#   'Psie Pole (Rondo Lotników Polskich)',
#   'Iwiny - rondo']]

# %%
from math import ceil

def generate_neighbourhood(path):
    neighborhood = set()
    mid_index = ceil(len(path) / 2)
    lower_half = path[:mid_index]
    
    for i in range(1, len(lower_half)):
        similar_solution = path[:]
        temp = similar_solution[len(similar_solution) - 1 - i]
        similar_solution[len(similar_solution) - 1 - i] = lower_half[i]
        similar_solution[i] = temp
        neighborhood.add(tuple(similar_solution))
    
    return [list(sol) for sol in neighborhood]

# %%
def tabu_search(graph, start, stops, departure_time):
    current_solution, _ = initial_solution_nn(graph, start, stops)
    best_solution = current_solution
    tabu_list = set()
    best_time, best_route = evaluate_solution(graph, best_solution, departure_time)

    k = 0
    while k < 30:
        i = 0
        while i < 10:
            neighbourhood = generate_neighbourhood(current_solution)
            best_neighbour = None
            best_neighbour_time = float('inf')
            best_neighbour_route = []

            neighbourhood = [neighbour for neighbour in neighbourhood if tuple(neighbour) not in tabu_list]

            for neighbour in neighbourhood:
                total_time, total_route = evaluate_solution(graph, neighbour, departure_time)
                if total_time < best_neighbour_time:
                    best_neighbour_time = total_time
                    best_neighbour = neighbour
                    best_neighbour_route = total_route

            if best_neighbour is None:
                break

            tabu_list.add(tuple(best_neighbour))

            if best_neighbour_time < best_time:
                best_solution = best_neighbour
                best_time = best_neighbour_time
                best_route = best_neighbour_route

            current_solution = best_neighbour

            i += 1
        k += 1
    
    return best_solution, best_time, best_route
       

start_station = "Stalowa"
#start_station= "KRZYKI"
stations_string = "most Grunwaldzki;Kochanowskiego;Wiśniowa;PL. JANA PAWŁA II"
#stations_string = "GRABISZYŃSKA (Cmentarz);ZOO;Urząd Wojewódzki (Muzeum Narodowe);most Grunwaldzki;Kochanowskiego;Wiśniowa;PL. JANA PAWŁA II"
#stations_string = "GRABISZYŃSKA (Cmentarz);Fiołkowa;FAT;Hutmen;Bzowa (Centrum Historii Zajezdnia)"
#stations_string = "Kliniki - Politechnika Wrocławska;BISKUPIN;Stalowa;Krucza;rondo Św. Ojca Pio;most Grunwaldzki;SĘPOLNO"
stations_string = "Tarczyński Arena (Lotnicza);Niedźwiedzia;Bujwida;PARK POŁUDNIOWY;Na Niskich Łąkach;BISKUPIN"


stations_string = stations_string.split(";")

tabu_search(graph, start_station, stations_string, "11:25:00")
# Out:
# (['Stalowa',
#   'Tarczyński Arena (Lotnicza)',
#   'PARK POŁUDNIOWY',
#   'Na Niskich Łąkach',
#   'Bujwida',
#   'BISKUPIN',
#   'Niedźwiedzia',
#   'Stalowa'],
#  206.0,
#  [Connection(14, 11:27:00 -> 11:29:00, Pereca),
#   Connection(14, 11:29:00 -> 11:30:00, Grabiszyńska),
#   Connection(14, 11:30:00 -> 11:31:00, Kolejowa),
#   Connection(14, 11:31:00 -> 11:33:00, pl. Legionów),
#   Connection(14, 11:33:00 -> 11:35:00, pl. Orląt Lwowskich),
#   Connection(14, 11:35:00 -> 11:37:00, PL. JANA PAWŁA II),
#   Connection(12, 11:39:00 -> 11:41:00, Młodych Techników),
#   Connection(12, 11:41:00 -> 11:42:00, pl. Strzegomski (Muzeum Współczesne)),
#   Connection(12, 11:42:00 -> 11:44:00, Wrocław Mikołajów (Zachodnia)),
#   Connection(12, 11:44:00 -> 11:46:00, Niedźwiedzia),
#   Connection(12, 11:46:00 -> 11:47:00, Małopanewska),
#   Connection(12, 11:47:00 -> 11:48:00, Kwiska),
#   Connection(20, 11:50:00 -> 11:52:00, DH Astra),
#   Connection(20, 11:52:00 -> 11:53:00, Park Zachodni),
#   Connection(20, 11:53:00 -> 11:54:00, Bajana),
#   Connection(20, 11:54:00 -> 11:56:00, Metalowców),
#   Connection(20, 11:56:00 -> 11:57:00, PILCZYCE),
#   Connection(20, 11:57:00 -> 11:59:00, Tarczyński Arena (Lotnicza)),
#   Connection(20, 12:03:00 -> 12:05:00, PILCZYCE),
#   Connection(20, 12:05:00 -> 12:06:00, Metalowców),
#   Connection(20, 12:06:00 -> 12:08:00, Bajana),
#   Connection(20, 12:08:00 -> 12:09:00, Park Zachodni),
#   Connection(20, 12:09:00 -> 12:10:00, DH Astra),
#   Connection(20, 12:10:00 -> 12:12:00, Kwiska),
#   Connection(20, 12:12:00 -> 12:13:00, Małopanewska),
#   Connection(20, 12:13:00 -> 12:15:00, Niedźwiedzia),
#   Connection(20, 12:15:00 -> 12:17:00, Wrocław Mikołajów (Zachodnia)),
#   Connection(20, 12:17:00 -> 12:18:00, Dolmed),
#   Connection(20, 12:18:00 -> 12:19:00, Śrubowa),
#   Connection(20, 12:19:00 -> 12:20:00, Smolecka),
#   Connection(20, 12:20:00 -> 12:22:00, Dworzec Świebodzki),
#   Connection(20, 12:22:00 -> 12:24:00, pl. Orląt Lwowskich),
#   Connection(20, 12:24:00 -> 12:28:00, Renoma),
#   Connection(20, 12:28:00 -> 12:30:00, Arkady (Capitol)),
#   Connection(15, 12:32:00 -> 12:35:00, DWORZEC AUTOBUSOWY),
#   Connection(15, 12:35:00 -> 12:37:00, Sanocka),
#   Connection(15, 12:37:00 -> 12:38:00, Uniwersytet Ekonomiczny),
#   Connection(15, 12:38:00 -> 12:40:00, Wiśniowa),
#   Connection(15, 12:40:00 -> 12:41:00, Jaworowa),
#   Connection(15, 12:41:00 -> 12:42:00, Weigla (Szpital)),
#   Connection(15, 12:42:00 -> 12:43:00, Pułtuska),
#   Connection(15, 12:43:00 -> 12:44:00, PARK POŁUDNIOWY),
#   Connection(9, 12:45:00 -> 12:46:00, Pułtuska),
#   Connection(9, 12:46:00 -> 12:47:00, Weigla (Szpital)),
#   Connection(9, 12:47:00 -> 12:48:00, Jaworowa),
#   Connection(9, 12:48:00 -> 12:49:00, Wiśniowa),
#   Connection(9, 12:49:00 -> 12:51:00, Uniwersytet Ekonomiczny),
#   Connection(9, 12:51:00 -> 12:52:00, Sanocka),
#   Connection(9, 12:52:00 -> 12:55:00, DWORZEC AUTOBUSOWY),
#   Connection(110, 12:57:00 -> 12:59:00, Hubska (Dawida)),
#   Connection(16, 13:03:00 -> 13:06:00, Kościuszki),
#   Connection(114, 13:09:00 -> 13:10:00, Świstackiego),
#   Connection(114, 13:10:00 -> 13:12:00, Na Niskich Łąkach),
#   Connection(3, 13:14:00 -> 13:16:00, pl. Zgody (Muzeum Etnograficzne)),
#   Connection(3, 13:16:00 -> 13:19:00, pl. Wróblewskiego),
#   Connection(4, 13:21:00 -> 13:23:00, Urząd Wojewódzki (Impart)),
#   Connection(4, 13:23:00 -> 13:25:00, most Grunwaldzki),
#   Connection(4, 13:25:00 -> 13:27:00, PL. GRUNWALDZKI),
#   Connection(12, 13:29:00 -> 13:31:00, Bujwida),
#   Connection(12, 13:31:00 -> 13:33:00, Kochanowskiego),
#   Connection(12, 13:33:00 -> 13:34:00, Chopina),
#   Connection(12, 13:34:00 -> 13:35:00, Karłowicza),
#   Connection(12, 13:35:00 -> 13:36:00, Stadion Olimpijski),
#   Connection(12, 13:36:00 -> 13:37:00, 8 Maja),
#   Connection(143, 13:40:00 -> 13:42:00, Dembowskiego (Kosiby)),
#   Connection(143, 13:42:00 -> 13:43:00, Chełmońskiego),
#   Connection(4, 13:46:00 -> 13:47:00, Piramowicza (Kampus Biskupin)),
#   Connection(4, 13:47:00 -> 13:48:00, Spółdzielcza),
#   Connection(4, 13:48:00 -> 13:50:00, BISKUPIN),
#   Connection(345, 13:51:00 -> 13:52:00, Spółdzielcza),
#   Connection(345, 13:52:00 -> 13:53:00, Piramowicza (Kampus Biskupin)),
#   Connection(345, 13:53:00 -> 13:54:00, Chełmońskiego),
#   Connection(345, 13:54:00 -> 13:56:00, Tramwajowa),
#   Connection(345, 13:56:00 -> 13:58:00, Hala Stulecia),
#   Connection(10, 14:01:00 -> 14:03:00, Kliniki - Politechnika Wrocławska),
#   Connection(10, 14:03:00 -> 14:05:00, PL. GRUNWALDZKI),
#   Connection(10, 14:05:00 -> 14:06:00, Reja),
#   Connection(10, 14:06:00 -> 14:08:00, Katedra),
#   Connection(10, 14:08:00 -> 14:10:00, Urząd Wojewódzki (Muzeum Narodowe)),
#   Connection(10, 14:10:00 -> 14:14:00, GALERIA DOMINIKAŃSKA),
#   Connection(10, 14:14:00 -> 14:16:00, Świdnicka),
#   Connection(10, 14:16:00 -> 14:17:00, Zamkowa),
#   Connection(10, 14:17:00 -> 14:19:00, Rynek),
#   Connection(10, 14:19:00 -> 14:22:00, PL. JANA PAWŁA II),
#   Connection(10, 14:22:00 -> 14:24:00, Młodych Techników),
#   Connection(10, 14:24:00 -> 14:25:00, pl. Strzegomski (Muzeum Współczesne)),
#   Connection(10, 14:25:00 -> 14:27:00, Wrocław Mikołajów (Zachodnia)),
#   Connection(10, 14:27:00 -> 14:29:00, Niedźwiedzia),
#   Connection(10, 14:29:00 -> 14:31:00, Wrocław Mikołajów (Zachodnia)),
#   Connection(10, 14:31:00 -> 14:33:00, pl. Strzegomski (Muzeum Współczesne)),
#   Connection(10, 14:33:00 -> 14:34:00, Młodych Techników),
#   Connection(10, 14:34:00 -> 14:36:00, PL. JANA PAWŁA II),
#   Connection(22, 14:39:00 -> 14:41:00, pl. Orląt Lwowskich),
#   Connection(22, 14:41:00 -> 14:43:00, pl. Legionów),
#   Connection(4, 14:45:00 -> 14:46:00, Kolejowa),
#   Connection(4, 14:46:00 -> 14:47:00, Grabiszyńska),
#   Connection(4, 14:47:00 -> 14:49:00, Pereca),
#   Connection(4, 14:49:00 -> 14:51:00, Stalowa)])
